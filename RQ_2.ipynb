# %%
from google.colab import drive
import pandas as pd
import json

# Mount Google Drive
drive.mount("/content/drive", force_remount=True)

# Dataset and Target Variables file paths
datasetPath = "/content/drive/My Drive/ECS 260/ECS 260 Project/clean-apache-network-data.csv"
targetVariablePath = "/content/drive/My Drive/ECS 260/ECS 260 Project/apache_project_status.json"

# Load dataset
df = pd.read_csv(datasetPath)
with open(targetVariablePath, 'r') as f:
    json_data = json.load(f)
# Out:
# Mounted at /content/drive

# %%
print("Dataset:")
display(df)
# Out:
# Dataset:
#       s_num_nodes  s_weighted_mean_degree  s_num_component  \
# 0              13               74.153846                1
# 1              15               34.133333                1
# 2              18               22.000000                2
# 3              15               22.666667                1
# 4              16               19.000000                2
# ...           ...                     ...              ...
# 6199            6                8.000000                1
# 6200           17               16.470588                1
# 6201           11                8.000000                1
# 6202           16               15.750000                1
# 6203           16               12.500000                1
#
#       s_avg_clustering_coef  s_largest_component  s_graph_density  \
# 0                  0.687463                   13         0.384615
# 1                  0.392751                   15         0.247619
# 2                  0.399824                   14         0.156863
# 3                  0.449899                   15         0.228571
# 4                  0.163095                   14         0.141667
# ...                     ...                  ...              ...
# 6199               0.388889                    6         0.466667
# 6200               0.332156                   17         0.161765
# 6201               0.308081                   11         0.218182
# 6202               0.283491                   16         0.216667
# 6203               0.578869                   16         0.233333
#
#       t_num_dev_nodes  t_num_file_nodes  t_num_dev_per_file  \
# 0                   2               201            1.059701
# 1                   3               218            1.252294
# 2                   3               171            1.140351
# 3                   1               195            1.000000
# 4                   2                72            1.069444
# ...               ...               ...                 ...
# 6199                3                30            1.033333
# 6200                6                91            1.076923
# 6201                9               831            1.599278
# 6202                7              1068            1.011236
# 6203                0                 0            0.000000
#
#       t_num_file_per_dev  t_graph_density proj_name  month  st_num_dev  \
# 0             106.500000         0.529851    abdera      0           1
# 1              91.000000         0.417431    abdera      1           2
# 2              65.000000         0.380117    abdera      2           2
# 3             195.000000         1.000000    abdera      3           0
# 4              38.500000         0.534722    abdera      4           1
# ...                  ...              ...       ...    ...         ...
# 6199           10.333333         0.344444    zipkin      4           1
# 6200           16.333333         0.179487    zipkin      5           2
# 6201          147.666667         0.177698    zipkin      6           2
# 6202          154.285714         0.144462    zipkin      7           2
# 6203            0.000000         0.000000    zipkin      8           0
#
#       t_net_overlap  s_net_overlap
# 0          0.000000       0.000000
# 1          0.191358       0.196429
# 2          0.147436       0.140000
# 3          0.235897       0.187500
# 4          0.139706       0.170732
# ...             ...            ...
# 6199       0.000000       0.142857
# 6200       0.115385       0.137931
# 6201       0.050420       0.235294
# 6202       0.269295       0.157895
# 6203       0.000000       0.185185
#
# [6204 rows x 16 columns]

# %%
print("\nTarget Variables:")
print(json.dumps(json_data, indent=4))
# Out:
# Target Variables:
# {
#     "graduated": [
#         "abdera",
#         "accumulo",
#         "ace",
#         "activemq",
#         "airavata",
#         "airflow",
#         "allura",
#         "ambari",
#         "oltu",
#         "any23",
#         "apex",
#         "apisix",
#         "apollo",
#         "aries",
#         "asterixdb",
#         "atlas",
#         "aurora",
#         "batchee",
#         "beam",
#         "bval",
#         "beehive",
#         "bigtop",
#         "bloodhound",
#         "brooklyn",
#         "buildr",
#         "calcite",
#         "carbondata",
#         "cassandra",
#         "cayenne",
#         "celix",
#         "chemistry",
#         "chukwa",
#         "clerezza",
#         "click",
#         "cloudstack",
#         "commonsrdf",
#         "cordova",
#         "couchdb",
#         "crunch",
#         "ctakes",
#         "curator",
#         "cxf",
#         "daffodil",
#         "datafu",
#         "datasketches",
#         "deltacloud",
#         "deltaspike",
#         "derby",
#         "devicemap",
#         "directmemory",
#         "directory",
#         "bookkeeper",
#         "dolphinscheduler",
#         "drill",
#         "druid",
#         "dubbo",
#         "eagle",
#         "ant",
#         "echarts",
#         "empire",
#         "esme",
#         "etch",
#         "falcon",
#         "felix",
#         "fineract",
#         "flex",
#         "flink",
#         "flume",
#         "fluo",
#         "freemarker",
#         "ftpserver",
#         "geode",
#         "geronimo",
#         "giraph",
#         "gobblin",
#         "gora",
#         "griffin",
#         "groovy",
#         "guacamole",
#         "hama",
#         "harmony",
#         "hawq",
#         "hcatalog",
#         "helix",
#         "pubscribe",
#         "httpd-cli",
#         "hudi",
#         "ibatis",
#         "iceberg",
#         "ignite",
#         "impala",
#         "iotdb",
#         "isis",
#         "ivy",
#         "jackrabbit",
#         "jaxme",
#         "jclouds",
#         "jdo",
#         "jena",
#         "johnzon",
#         "joshua",
#         "jspwiki",
#         "juddi",
#         "juneau",
#         "kafka",
#         "knox",
#         "kudu",
#         "kylin",
#         "lens",
#         "lenya",
#         "libcloud",
#         "log4cxx",
#         "log4cxx2",
#         "log4net",
#         "log4php",
#         "lucenenet",
#         "lucy",
#         "madlib",
#         "manifoldcf",
#         "marmotta",
#         "avalon",
#         "mesos",
#         "metamodel",
#         "metron",
#         "mnemonic",
#         "mod_ftp",
#         "mrunit",
#         "muse",
#         "myfaces",
#         "mynewt",
#         "netbeans",
#         "nifi",
#         "nutch",
#         "nuvem",
#         "ode",
#         "ofbiz",
#         "commons",
#         "olingo",
#         "omid",
#         "onami",
#         "oodt",
#         "oozie",
#         "climate",
#         "openejb",
#         "openjpa",
#         "openmeetings",
#         "opennlp",
#         "openoffice",
#         "openwebbeans",
#         "openwhisk",
#         "parquet",
#         "pdfbox",
#         "phoenix",
#         "pig",
#         "pinot",
#         "pivot",
#         "plc4x",
#         "pluto",
#         "predictionio",
#         "pulsar",
#         "qpid",
#         "ranger",
#         "rat",
#         "ratis",
#         "rave",
#         "reef",
#         "river",
#         "rocketmq",
#         "roller",
#         "rya",
#         "samza",
#         "sanselan",
#         "sentry",
#         "servicecomb",
#         "servicemix",
#         "shardingsphere",
#         "shindig",
#         "shiro",
#         "singa",
#         "sis",
#         "skywalking",
#         "sling",
#         "solr",
#         "spamassassin",
#         "spark",
#         "sqoop",
#         "stanbol",
#         "stdcxx",
#         "storm",
#         "stratos",
#         "streams",
#         "subversion",
#         "superset",
#         "synapse",
#         "syncope",
#         "systemml",
#         "tajo",
#         "tapestry",
#         "tephra",
#         "tez",
#         "thrift",
#         "tika",
#         "tinkerpop",
#         "myfaces",
#         "trafficcontrol",
#         "trafficserver",
#         "trafodion",
#         "adffaces",
#         "tuscany",
#         "tvm",
#         "twill",
#         "uima",
#         "unomi",
#         "usergrid",
#         "vcl",
#         "vxquery",
#         "struts",
#         "whirr",
#         "wicket",
#         "wink",
#         "woden",
#         "wookie",
#         "xmlbeans",
#         "zeppelin"
#     ],
#     "retired": [
#         "agila",
#         "alois",
#         "altrmi",
#         "amaterasu",
#         "ariatosca",
#         "awf",
#         "axion",
#         "bluesky",
#         "blur",
#         "cmda",
#         "composer",
#         "concerted",
#         "corinthia",
#         "cotton",
#         "depot",
#         "droids",
#         "edgent",
#         "gearpump",
#         "gossip",
#         "graffito",
#         "hdt",
#         "heraldry",
#         "hise",
#         "horn",
#         "htrace",
#         "imperius",
#         "iota",
#         "juice",
#         "kabuki",
#         "kalumet",
#         "kato",
#         "kitty",
#         "lokahi",
#         "lucene4c",
#         "mrql",
#         "myriad",
#         "nmaven",
#         "npanday",
#         "odf",
#         "olio",
#         "openaz",
#         "photark",
#         "pirk",
#         "provisionr",
#         "quickstep",
#         "rcf",
#         "ripple",
#         "s2graph",
#         "s4",
#         "samoa",
#         "sirona",
#         "slider",
#         "socialsite",
#         "stonehenge",
#         "tamaya",
#         "tashi",
#         "taverna",
#         "triplesoup",
#         "tsik",
#         "wadi",
#         "warble",
#         "wave",
#         "weex",
#         "wsrp4j",
#         "xap",
#         "xmlbeans-cxx",
#         "yoko",
#         "zeta",
#         "zipkin"
#     ],
#     "incubating": [
#         "age",
#         "annotator",
#         "bluemarlin",
#         "brpc",
#         "crail",
#         "datalab",
#         "doris",
#         "eventmesh",
#         "flagon",
#         "heron",
#         "hivemall",
#         "hop",
#         "inlong",
#         "kyuubi",
#         "liminal",
#         "linkis",
#         "livy",
#         "marvin",
#         "milagro",
#         "mxnet",
#         "nemo",
#         "nlpcraft",
#         "nuttx",
#         "pagespeed",
#         "pegasus",
#         "ponymail",
#         "sdap",
#         "sedona",
#         "shenyu",
#         "spot",
#         "streampipes",
#         "teaclave",
#         "toree",
#         "training",
#         "tuweni",
#         "wayang",
#         "yunikorn"
#     ]
# }

# %%
import json

targetVariables = {}

# Mark graduated projects as 1
for repo in json_data['graduated']:
    targetVariables[repo] = 1

# Mark retired projects as 0 and ignore incubating projects
for repo in json_data['retired']:
    targetVariables[repo] = 0

# Output the result
print(json.dumps(targetVariables, indent=4))
# Out:
# {
#     "abdera": 1,
#     "accumulo": 1,
#     "ace": 1,
#     "activemq": 1,
#     "airavata": 1,
#     "airflow": 1,
#     "allura": 1,
#     "ambari": 1,
#     "oltu": 1,
#     "any23": 1,
#     "apex": 1,
#     "apisix": 1,
#     "apollo": 1,
#     "aries": 1,
#     "asterixdb": 1,
#     "atlas": 1,
#     "aurora": 1,
#     "batchee": 1,
#     "beam": 1,
#     "bval": 1,
#     "beehive": 1,
#     "bigtop": 1,
#     "bloodhound": 1,
#     "brooklyn": 1,
#     "buildr": 1,
#     "calcite": 1,
#     "carbondata": 1,
#     "cassandra": 1,
#     "cayenne": 1,
#     "celix": 1,
#     "chemistry": 1,
#     "chukwa": 1,
#     "clerezza": 1,
#     "click": 1,
#     "cloudstack": 1,
#     "commonsrdf": 1,
#     "cordova": 1,
#     "couchdb": 1,
#     "crunch": 1,
#     "ctakes": 1,
#     "curator": 1,
#     "cxf": 1,
#     "daffodil": 1,
#     "datafu": 1,
#     "datasketches": 1,
#     "deltacloud": 1,
#     "deltaspike": 1,
#     "derby": 1,
#     "devicemap": 1,
#     "directmemory": 1,
#     "directory": 1,
#     "bookkeeper": 1,
#     "dolphinscheduler": 1,
#     "drill": 1,
#     "druid": 1,
#     "dubbo": 1,
#     "eagle": 1,
#     "ant": 1,
#     "echarts": 1,
#     "empire": 1,
#     "esme": 1,
#     "etch": 1,
#     "falcon": 1,
#     "felix": 1,
#     "fineract": 1,
#     "flex": 1,
#     "flink": 1,
#     "flume": 1,
#     "fluo": 1,
#     "freemarker": 1,
#     "ftpserver": 1,
#     "geode": 1,
#     "geronimo": 1,
#     "giraph": 1,
#     "gobblin": 1,
#     "gora": 1,
#     "griffin": 1,
#     "groovy": 1,
#     "guacamole": 1,
#     "hama": 1,
#     "harmony": 1,
#     "hawq": 1,
#     "hcatalog": 1,
#     "helix": 1,
#     "pubscribe": 1,
#     "httpd-cli": 1,
#     "hudi": 1,
#     "ibatis": 1,
#     "iceberg": 1,
#     "ignite": 1,
#     "impala": 1,
#     "iotdb": 1,
#     "isis": 1,
#     "ivy": 1,
#     "jackrabbit": 1,
#     "jaxme": 1,
#     "jclouds": 1,
#     "jdo": 1,
#     "jena": 1,
#     "johnzon": 1,
#     "joshua": 1,
#     "jspwiki": 1,
#     "juddi": 1,
#     "juneau": 1,
#     "kafka": 1,
#     "knox": 1,
#     "kudu": 1,
#     "kylin": 1,
#     "lens": 1,
#     "lenya": 1,
#     "libcloud": 1,
#     "log4cxx": 1,
#     "log4cxx2": 1,
#     "log4net": 1,
#     "log4php": 1,
#     "lucenenet": 1,
#     "lucy": 1,
#     "madlib": 1,
#     "manifoldcf": 1,
#     "marmotta": 1,
#     "avalon": 1,
#     "mesos": 1,
#     "metamodel": 1,
#     "metron": 1,
#     "mnemonic": 1,
#     "mod_ftp": 1,
#     "mrunit": 1,
#     "muse": 1,
#     "myfaces": 1,
#     "mynewt": 1,
#     "netbeans": 1,
#     "nifi": 1,
#     "nutch": 1,
#     "nuvem": 1,
#     "ode": 1,
#     "ofbiz": 1,
#     "commons": 1,
#     "olingo": 1,
#     "omid": 1,
#     "onami": 1,
#     "oodt": 1,
#     "oozie": 1,
#     "climate": 1,
#     "openejb": 1,
#     "openjpa": 1,
#     "openmeetings": 1,
#     "opennlp": 1,
#     "openoffice": 1,
#     "openwebbeans": 1,
#     "openwhisk": 1,
#     "parquet": 1,
#     "pdfbox": 1,
#     "phoenix": 1,
#     "pig": 1,
#     "pinot": 1,
#     "pivot": 1,
#     "plc4x": 1,
#     "pluto": 1,
#     "predictionio": 1,
#     "pulsar": 1,
#     "qpid": 1,
#     "ranger": 1,
#     "rat": 1,
#     "ratis": 1,
#     "rave": 1,
#     "reef": 1,
#     "river": 1,
#     "rocketmq": 1,
#     "roller": 1,
#     "rya": 1,
#     "samza": 1,
#     "sanselan": 1,
#     "sentry": 1,
#     "servicecomb": 1,
#     "servicemix": 1,
#     "shardingsphere": 1,
#     "shindig": 1,
#     "shiro": 1,
#     "singa": 1,
#     "sis": 1,
#     "skywalking": 1,
#     "sling": 1,
#     "solr": 1,
#     "spamassassin": 1,
#     "spark": 1,
#     "sqoop": 1,
#     "stanbol": 1,
#     "stdcxx": 1,
#     "storm": 1,
#     "stratos": 1,
#     "streams": 1,
#     "subversion": 1,
#     "superset": 1,
#     "synapse": 1,
#     "syncope": 1,
#     "systemml": 1,
#     "tajo": 1,
#     "tapestry": 1,
#     "tephra": 1,
#     "tez": 1,
#     "thrift": 1,
#     "tika": 1,
#     "tinkerpop": 1,
#     "trafficcontrol": 1,
#     "trafficserver": 1,
#     "trafodion": 1,
#     "adffaces": 1,
#     "tuscany": 1,
#     "tvm": 1,
#     "twill": 1,
#     "uima": 1,
#     "unomi": 1,
#     "usergrid": 1,
#     "vcl": 1,
#     "vxquery": 1,
#     "struts": 1,
#     "whirr": 1,
#     "wicket": 1,
#     "wink": 1,
#     "woden": 1,
#     "wookie": 1,
#     "xmlbeans": 1,
#     "zeppelin": 1,
#     "agila": 0,
#     "alois": 0,
#     "altrmi": 0,
#     "amaterasu": 0,
#     "ariatosca": 0,
#     "awf": 0,
#     "axion": 0,
#     "bluesky": 0,
#     "blur": 0,
#     "cmda": 0,
#     "composer": 0,
#     "concerted": 0,
#     "corinthia": 0,
#     "cotton": 0,
#     "depot": 0,
#     "droids": 0,
#     "edgent": 0,
#     "gearpump": 0,
#     "gossip": 0,
#     "graffito": 0,
#     "hdt": 0,
#     "heraldry": 0,
#     "hise": 0,
#     "horn": 0,
#     "htrace": 0,
#     "imperius": 0,
#     "iota": 0,
#     "juice": 0,
#     "kabuki": 0,
#     "kalumet": 0,
#     "kato": 0,
#     "kitty": 0,
#     "lokahi": 0,
#     "lucene4c": 0,
#     "mrql": 0,
#     "myriad": 0,
#     "nmaven": 0,
#     "npanday": 0,
#     "odf": 0,
#     "olio": 0,
#     "openaz": 0,
#     "photark": 0,
#     "pirk": 0,
#     "provisionr": 0,
#     "quickstep": 0,
#     "rcf": 0,
#     "ripple": 0,
#     "s2graph": 0,
#     "s4": 0,
#     "samoa": 0,
#     "sirona": 0,
#     "slider": 0,
#     "socialsite": 0,
#     "stonehenge": 0,
#     "tamaya": 0,
#     "tashi": 0,
#     "taverna": 0,
#     "triplesoup": 0,
#     "tsik": 0,
#     "wadi": 0,
#     "warble": 0,
#     "wave": 0,
#     "weex": 0,
#     "wsrp4j": 0,
#     "xap": 0,
#     "xmlbeans-cxx": 0,
#     "yoko": 0,
#     "zeta": 0,
#     "zipkin": 0
# }

# %%
target_df = pd.DataFrame(targetVariables.items(), columns=['proj_name', 'graduated'])
target_df
# Out:
#         proj_name  graduated
# 0          abdera          1
# 1        accumulo          1
# 2             ace          1
# 3        activemq          1
# 4        airavata          1
# ..            ...        ...
# 287           xap          0
# 288  xmlbeans-cxx          0
# 289          yoko          0
# 290          zeta          0
# 291        zipkin          0
#
# [292 rows x 2 columns]

# %%
df = df.merge(target_df, on='proj_name', how='inner')
df
# Out:
#       s_num_nodes  s_weighted_mean_degree  s_num_component  \
# 0              13               74.153846                1
# 1              15               34.133333                1
# 2              18               22.000000                2
# 3              15               22.666667                1
# 4              16               19.000000                2
# ...           ...                     ...              ...
# 6199            6                8.000000                1
# 6200           17               16.470588                1
# 6201           11                8.000000                1
# 6202           16               15.750000                1
# 6203           16               12.500000                1
#
#       s_avg_clustering_coef  s_largest_component  s_graph_density  \
# 0                  0.687463                   13         0.384615
# 1                  0.392751                   15         0.247619
# 2                  0.399824                   14         0.156863
# 3                  0.449899                   15         0.228571
# 4                  0.163095                   14         0.141667
# ...                     ...                  ...              ...
# 6199               0.388889                    6         0.466667
# 6200               0.332156                   17         0.161765
# 6201               0.308081                   11         0.218182
# 6202               0.283491                   16         0.216667
# 6203               0.578869                   16         0.233333
#
#       t_num_dev_nodes  t_num_file_nodes  t_num_dev_per_file  \
# 0                   2               201            1.059701
# 1                   3               218            1.252294
# 2                   3               171            1.140351
# 3                   1               195            1.000000
# 4                   2                72            1.069444
# ...               ...               ...                 ...
# 6199                3                30            1.033333
# 6200                6                91            1.076923
# 6201                9               831            1.599278
# 6202                7              1068            1.011236
# 6203                0                 0            0.000000
#
#       t_num_file_per_dev  t_graph_density proj_name  month  st_num_dev  \
# 0             106.500000         0.529851    abdera      0           1
# 1              91.000000         0.417431    abdera      1           2
# 2              65.000000         0.380117    abdera      2           2
# 3             195.000000         1.000000    abdera      3           0
# 4              38.500000         0.534722    abdera      4           1
# ...                  ...              ...       ...    ...         ...
# 6199           10.333333         0.344444    zipkin      4           1
# 6200           16.333333         0.179487    zipkin      5           2
# 6201          147.666667         0.177698    zipkin      6           2
# 6202          154.285714         0.144462    zipkin      7           2
# 6203            0.000000         0.000000    zipkin      8           0
#
#       t_net_overlap  s_net_overlap  graduated
# 0          0.000000       0.000000          1
# 1          0.191358       0.196429          1
# 2          0.147436       0.140000          1
# 3          0.235897       0.187500          1
# 4          0.139706       0.170732          1
# ...             ...            ...        ...
# 6199       0.000000       0.142857          0
# 6200       0.115385       0.137931          0
# 6201       0.050420       0.235294          0
# 6202       0.269295       0.157895          0
# 6203       0.000000       0.185185          0
#
# [6204 rows x 17 columns]

# %% [markdown]
# # RQ#2 - Haseeb & Aayusha

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.violinplot(
    data=df,
    x='graduated',
    y='s_num_nodes',
    inner='stick',
    hue='graduated',
    palette=['red', 'green'],
    legend=False
)
plt.title('Bean Plot of s_num_nodes by Graduation Status')
plt.xlabel('Graduated (0 = Retired, 1 = Graduated)')
plt.ylabel('s_num_nodes')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='graduated', y='s_net_overlap', hue='graduated', palette={0: 'red', 1: 'green'}, width=0.4)
sns.stripplot(data=df, x='graduated', y='s_net_overlap', jitter=True, alpha=0.5, color='black')
plt.title("Network Overlap (s_net_overlap) for Graduated vs. Retired Projects")
plt.xlabel("Graduation Status (0 = Retired, 1 = Graduated)")
plt.ylabel("s_net_overlap")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.regplot(data=df, x='graduated', y='s_net_overlap', scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
plt.title('Network Overlap vs Graduation Status')
plt.show()
print()

# Time series representation
plt.figure(figsize=(12,6))
sns.lineplot(data=df, x='month', y='s_net_overlap', hue='graduated', style='graduated', markers=True)
plt.title('Network Overlap Over Time by Graduation Status')
plt.show()

# %%
g = sns.FacetGrid(df, col="graduated", hue="graduated", height=5, aspect=1.5)
g.map_dataframe(sns.lineplot, x="month", y="s_num_nodes")
g.add_legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 10))

metrics = ['s_num_nodes', 't_num_dev_per_file', 's_weighted_mean_degree', 's_net_overlap', 't_net_overlap']
titles = ["Number of Nodes Over Time", "Developers per File Over Time",
          "Weighted Mean Degree Over Time", "Structural Network Overlap Over Time", "Temporal Network Overlap Over Time"]

fig, axes = plt.subplots(3, 2, figsize=(15, 12))

for i, metric in enumerate(metrics):
    ax = axes[i//2, i%2]
    sns.lineplot(data=df, x='month', y=metric, hue='graduated', style='graduated', markers=True, ax=ax)
    ax.set_title(titles[i])
    ax.set_xlabel("Month")
    ax.set_ylabel(metric)

fig.delaxes(axes[2, 1])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

metrics = ['s_num_nodes', 't_num_dev_per_file', 's_weighted_mean_degree', 's_net_overlap', 't_net_overlap']

scaler = MinMaxScaler()
df[metrics] = scaler.fit_transform(df[metrics])

g = sns.FacetGrid(df.melt(id_vars=['month', 'graduated'], value_vars=metrics), col="variable", hue="graduated", height=4, aspect=1.5, sharex=True, sharey=False)
g.map_dataframe(sns.lineplot, x="month", y="value")
g.add_legend()
plt.suptitle("Trend of Normalized Metrics Over Time by Graduated/Retired Projects", y=1.05, fontsize=14)
plt.show()

# %%
# #RQ2 - CORRELATION MATRIX

# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
# from scipy.stats import pearsonr

# # Assuming your final dataframe is df, with the columns:
# # 'proj_name', 's_num_nodes', 't_num_dev_per_file', 's_weighted_mean_degree', 's_net_overlap', 't_net_overlap', and 'graduated'

# # Aggregate the metrics by project (proj_name) and calculate the mean across months
# aggregated_df = df.groupby('proj_name').agg({
#     's_num_nodes': 'mean',
#     't_num_dev_per_file': 'mean',
#     's_weighted_mean_degree': 'mean',
#     's_net_overlap': 'mean',
#     't_net_overlap': 'mean',
#     'graduated': 'mean'  # Assuming 'graduated' is a binary variable (0 or 1)
# }).reset_index()

# # Calculate the correlation matrix to understand relationships between the variables
# corr_matrix = aggregated_df[['s_num_nodes', 't_num_dev_per_file', 's_weighted_mean_degree',
#                              's_net_overlap', 't_net_overlap', 'graduated']].corr()

# # Visualize the correlation matrix
# plt.figure(figsize=(10, 6))
# sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, fmt='.2f', linewidths=0.5)
# plt.title('Correlation Matrix between Metrics and Graduated Status')
# plt.show()

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

ROLLING_WINDOW = 12

df['month'] = pd.to_datetime(df['month'])
df_sorted = df.sort_values(by=['proj_name', 'month'])
df_rolling = df_sorted.groupby('proj_name').rolling(ROLLING_WINDOW, on='month').mean().reset_index()

aggregated_df = df_rolling.groupby('proj_name').agg({
    's_num_nodes': 'mean',
    't_num_dev_per_file': 'mean',
    's_weighted_mean_degree': 'mean',
    's_net_overlap': 'mean',
    't_net_overlap': 'mean',
    'graduated': 'mean'
}).reset_index()

corr_matrix = aggregated_df[['s_num_nodes', 't_num_dev_per_file', 's_weighted_mean_degree',
                             's_net_overlap', 't_net_overlap', 'graduated']].corr()

plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix between Metrics and Graduated Status')
plt.show()

# %%
# #RQ2 -BOX PLOT

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

ROLLING_WINDOW = 12
df['month'] = pd.to_datetime(df['month'])
df_sorted = df.sort_values(by=['proj_name', 'month'])
df_rolling = df_sorted.groupby('proj_name').rolling(ROLLING_WINDOW, on='month').mean().reset_index()
aggregated_df = df_rolling.groupby('proj_name').agg({
    's_num_nodes': 'mean',
    't_num_dev_per_file': 'mean',
    's_weighted_mean_degree': 'mean',
    's_net_overlap': 'mean',
    't_net_overlap': 'mean',
    'graduated': 'mean'
}).reset_index()
aggregated_df['graduated'] = aggregated_df['graduated'].fillna(0).round().astype(int)
metrics = ['s_num_nodes', 't_num_dev_per_file', 's_weighted_mean_degree', 's_net_overlap', 't_net_overlap']
plt.figure(figsize=(12, 8))

for i, metric in enumerate(metrics, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(x='graduated', y=metric, data=aggregated_df, hue='graduated', palette="coolwarm", legend=False)
    plt.xlabel("Graduation Status (0 = No, 1 = Yes)")
    plt.ylabel(metric.replace('_', ' ').title())
    plt.title(f"{metric.replace('_', ' ').title()} vs. Graduation")
plt.tight_layout()
plt.show()
