# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd


url = "https://incubator.apache.org/clutch/"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")
rows = soup.find_all('tr')

data_list = []
for row in rows[1:]:
    cols = row.find_all('td')
    data = {
        "Podling": cols[0].get_text(strip=True),
        "Sponsor": cols[1].get_text(strip=True),
        "start_date": cols[2].get_text(strip=True),
        "elapsed_days": cols[3].get_text(strip=True),
        "reporting_monthly": cols[4].get_text(strip=True),
        "reporting_group": cols[5].get_text(strip=True),
        "has_status_file": cols[6].get_text(strip=True),
        "status_update_date": cols[7].get_text(strip=True),
        "status_age": cols[8].get_text(strip=True),
        "status_update_counts": cols[9].get_text(strip=True),
        "no_of_committers": cols[10].get_text(strip=True),
        "no_of_new_committers": cols[11].get_text(strip=True),
        "has_a_code_repo": cols[12].get_text(strip=True),
        "has_issue_tracker": cols[13].get_text(strip=True),
        "has_a_dev_mailing_list": cols[14].get_text(strip=True),
        "has_a_commits_mailing_list": cols[15].get_text(strip=True),
        "has_website": cols[16].get_text(strip=True),
        "has_distribution_area": cols[17].get_text(strip=True),
        "has_release_signing_keys": cols[18].get_text(strip=True),
        "has_release_distribution_area": cols[19].get_text(strip=True),
    }
    data_list.append(data)

df = pd.DataFrame(data_list)
df = df.iloc[:-1]  # Remove the last row
display(df)
# Out:
# /Users/haseebrahman/Desktop/Projects/SEProject-Team4-The-Popularity-Paradigm/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
#            Podling    Sponsor  start_date elapsed_days reporting_monthly  \
# 0            Amoro  Incubator  2024-03-11          364             False
# 1        Annotator  Incubator  2016-08-30         3114             False
# 2         Baremaps  Incubator  2022-10-10          882             False
# 3       Cloudberry  Incubator  2024-10-11          150             False
# 4          DevLake  Incubator  2022-04-29         1046             False
# 5             Fury  Incubator  2023-12-15          451             False
# 6           Gluten  Incubator  2024-01-11          424             False
# 7           Grails     Groovy  2025-01-25           44             False
# 8          GraphAr  Incubator  2024-03-25          350             False
# 9        Gravitino  Incubator  2024-06-04          279              True
# 10       HertzBeat  Incubator  2024-04-05          339             False
# 11         HoraeDB  Incubator  2023-12-11          455             False
# 12       HugeGraph  Incubator  2022-01-23         1142             False
# 13            Iggy  Incubator  2025-02-04           34              True
# 14             KIE  Incubator  2023-01-13          787             False
# 15            Livy  Incubator  2017-06-05         2835             False
# 16            Nemo  Incubator  2018-02-04         2591              True
# 17        NLPCraft  Incubator  2020-02-13         1852             False
# 18  OpenServerless  Incubator  2024-06-17          266             False
# 19           Otava  Incubator  2024-11-27          103             False
# 20          OzHera  Incubator  2024-07-11          242             False
# 21         Pegasus  Incubator  2020-06-28         1716             False
# 22         Polaris  Incubator  2024-08-09          213             False
# 23       Pony Mail  Incubator  2016-05-27         3209              True
# 24     ResilientDB  Incubator  2023-10-21          506             False
# 25           Seata             2023-10-29          498             False
# 26    StormCrawler  Incubator  2024-03-19          356             False
# 27        Teaclave  Incubator  2019-08-20         2029              True
# 28           Toree  Incubator  2015-12-02         3386              True
# 29        Training  Incubator  2019-02-21         2209              True
# 30          Wayang  Incubator  2020-12-16         1545             False
# 31          XTable  Incubator  2024-02-11          393             False
#
#    reporting_group has_status_file status_update_date status_age  \
# 0                1            True         2024-03-19        356
# 1                1            True         2020-10-09       1613
# 2                3            True         2022-10-20        872
# 3                2            True         2024-12-05         95
# 4                2            True         2022-05-12       1033
# 5                2            True         2023-12-16        450
# 6                1            True         2024-01-15        420
# 7                1            True         2025-03-10          0
# 8                2            True         2024-04-07        337
# 9                3           False                             0
# 10               1            True         2024-04-11        333
# 11               2            True         2023-12-16        450
# 12               1            True         2024-12-13         87
# 13               3            True         2025-03-07          3
# 14               3            True         2024-02-13        391
# 15               1            True         2017-06-23       2817
# 16               3            True         2018-03-01       2566
# 17               2            True         2020-10-08       1614
# 18               3            True         2024-07-20        233
# 19               3            True         2025-02-21         17
# 20               3           False                             0
# 21               1            True         2023-12-20        446
# 22               3            True         2024-08-27        195
# 23               1            True         2024-07-19        234
# 24               1            True         2024-04-11        333
# 25               2            True         2023-12-02        464
# 26               1            True         2024-03-29        346
# 27               1            True         2023-04-04        706
# 28               2            True         2020-07-19       1695
# 29               2            True         2019-02-28       2202
# 30               3            True         2021-01-22       1508
# 31               2            True         2024-05-16        298
#
#    status_update_counts no_of_committers no_of_new_committers has_a_code_repo  \
# 0                 0,0,0               24                    0            True
# 1                 0,0,0                8                    0            True
# 2                 0,0,0               14                    0            True
# 3                 0,1,4               24                    0            True
# 4                 0,0,0               34                    0            True
# 5                 0,0,0               12                    0            True
# 6                 0,0,0               37                    0            True
# 7                 4,-,-                9                    0           False
# 8                 0,0,0               11                    0            True
# 9                                     25                    0            True
# 10                0,0,0               25                    0            True
# 11                0,0,0               15                    0            True
# 12                0,1,1               18                    6            True
# 13                3,-,-               12                    0            True
# 14                0,0,0               64                    0            True
# 15                0,0,0               24                    0            True
# 16                0,0,0               18                    0            True
# 17                0,0,0               10                    1            True
# 18                0,0,2               13                    0            True
# 19                2,4,-                9                    1            True
# 20                                    13                    0            True
# 21                0,0,0               19                    5            True
# 22                0,0,1               21                    0            True
# 23                0,0,1               11                    0            True
# 24                0,0,0               31                    0            True
# 25                0,0,0               30                    0            True
# 26                0,0,0               10                    0            True
# 27                0,0,0               25                    3            True
# 28                0,0,0               11                    3            True
# 29                0,0,0               17                    0            True
# 30                0,0,0               16                    0            True
# 31                0,0,0               10                    0            True
#
#    has_issue_tracker has_a_dev_mailing_list has_a_commits_mailing_list  \
# 0               True                   True                       True
# 1               True                  False                      False
# 2               True                   True                       True
# 3              False                   True                       True
# 4               True                   True                       True
# 5               True                   True                       True
# 6               True                   True                       True
# 7              False                   True                       True
# 8               True                   True                       True
# 9              False                  False                      False
# 10              True                   True                       True
# 11              True                   True                       True
# 12              True                   True                      False
# 13             False                   True                       True
# 14             False                   True                       True
# 15             False                  False                      False
# 16              True                   True                       True
# 17             False                  False                      False
# 18              True                   True                       True
# 19             False                   True                       True
# 20             False                  False                      False
# 21              True                   True                       True
# 22              True                   True                       True
# 23              True                   True                       True
# 24             False                   True                      False
# 25              True                   True                       True
# 26              True                   True                       True
# 27             False                  False                      False
# 28              True                  False                      False
# 29              True                   True                       True
# 30             False                   True                       True
# 31             False                   True                       True
#
#    has_website has_distribution_area has_release_signing_keys  \
# 0         True                  True                     True
# 1         True                  True                     True
# 2         True                  True                     True
# 3         True                 False                    False
# 4         True                  True                     True
# 5         True                  True                     True
# 6         True                  True                     True
# 7        False                 False                    False
# 8         True                  True                     True
# 9         True                  True                     True
# 10        True                  True                     True
# 11        True                  True                     True
# 12        True                  True                     True
# 13        True                 False                    False
# 14        True                  True                     True
# 15        True                  True                     True
# 16        True                  True                     True
# 17        True                  True                     True
# 18        True                 False                    False
# 19       False                 False                    False
# 20        True                  True                     True
# 21        True                  True                     True
# 22        True                  True                     True
# 23        True                  True                     True
# 24        True                  True                     True
# 25        True                  True                     True
# 26        True                  True                     True
# 27        True                  True                     True
# 28        True                  True                     True
# 29        True                  True                     True
# 30        True                  True                     True
# 31        True                  True                     True
#
#    has_release_distribution_area
# 0                           True
# 1                           True
# 2                           True
# 3                          False
# 4                           True
# 5                           True
# 6                           True
# 7                          False
# 8                           True
# 9                           True
# 10                          True
# 11                          True
# 12                          True
# 13                         False
# 14                          True
# 15                          True
# 16                          True
# 17                          True
# 18                         False
# 19                         False
# 20                         False
# 21                          True
# 22                          True
# 23                          True
# 24                          True
# 25                          True
# 26                          True
# 27                          True
# 28                          True
# 29                          True
# 30                          True
# 31                          True

# %%
import requests
import lxml.html as lx
import time
import json

podling_names = df['Podling'].tolist()
podlings = podling_names
BASE_URL = "https://incubator.apache.org/projects/"
HEADERS = {"User-Agent": "Mozilla/5.0"}

github_urls = {}
def get_github_url(podling):
    podling_url = f"{BASE_URL}{podling.lower()}.html"
    response = requests.get(podling_url, headers=HEADERS)

    if response.status_code == 200:
        tree = lx.fromstring(response.content)
        github_links = tree.xpath('//a[contains(@href, "github.com/apache")]/@href')

        if github_links:
            github_url = github_links[0]
            github_url = github_url.split("/issues")[0]
            return github_url
        else:
            return "GitHub URL not found"
    else:
        return "Page not found"

for podling in podlings:
    github_urls[podling] = get_github_url(podling)
    print(f"{podling}: {github_urls[podling]}")
    time.sleep(1)
# Out:
# Amoro: https://github.com/apache/incubator-amoro
# Annotator: GitHub URL not found
# Baremaps: https://github.com/apache/baremaps
# Cloudberry: https://github.com/apache/cloudberry/
# DevLake: https://github.com/apache/incubator-devlake
# Fury: https://github.com/apache/incubator-fury
# Gluten: GitHub URL not found
# Grails: GitHub URL not found
# GraphAr: https://github.com/apache/incubator-graphar
# Gravitino: Page not found
# HertzBeat: https://github.com/apache/hertzbeat
# HoraeDB: https://github.com/apache/incubator-horaedb
# HugeGraph: https://github.com/apache/hugegraph
# Iggy: https://github.com/apache/iggy
# KIE: https://github.com/apache/incubator-kie-issues
# Livy: GitHub URL not found
# Nemo: GitHub URL not found
# NLPCraft: GitHub URL not found
# OpenServerless: https://github.com/apache/openserverless
# Otava: https://github.com/apache/otava/
# OzHera: Page not found
# Pegasus: GitHub URL not found
# Polaris: https://github.com/apache/polaris
# Pony Mail: Page not found
# ResilientDB: GitHub URL not found
# Seata: https://github.com/apache/incubator-seata
# StormCrawler: https://github.com/apache/incubator-stormcrawler
# Teaclave: GitHub URL not found
# Toree: https://github.com/apache/incubator-toree
# Training: GitHub URL not found
# Wayang: GitHub URL not found
# XTable: https://github.com/apache/incubator-xtable

# %%
# Handle edge cases of github url scraping
github_urls["Annotator"] = "https://github.com/apache/incubator-annotator"
github_urls["Gluten"] = "https://github.com/apache/incubator-gluten"
github_urls["Grails"] = "https://github.com/grails/grails-core"
github_urls["Gravitino"] = "https://github.com/apache/gravitino"
github_urls["Livy"] = "https://github.com/apache/incubator-livy"
github_urls["Nemo"] = "https://github.com/apache/incubator-nemo"
github_urls["NLPCraft"] = "https://github.com/apache/incubator-nlpcraft"
github_urls["OzHera"] = "https://github.com/apache/ozhera"
github_urls["Pegasus"] = "https://github.com/apache/incubator-pegasus"
github_urls["Pony Mail"] = "https://github.com/apache/incubator-ponymail"
github_urls["ResilientDB"] = "https://github.com/apache/incubator-resilientdb"
github_urls["Teaclave"] = "https://github.com/apache/incubator-teaclave"
github_urls["Training"] = "https://github.com/apache/incubator-training"
github_urls["Wayang"] = "https://github.com/apache/incubator-wayang"
github_urls["Otava"] = "https://github.com/apache/hunter"
github_urls["Uniffle"] = "https://github.com/apache/incubator-uniffle"
github_urls["Iggy"] = "https://github.com/iggy-rs/iggy"
display(github_urls)
# Out:
# {'Amoro': 'https://github.com/apache/incubator-amoro',
#  'Annotator': 'https://github.com/apache/incubator-annotator',
#  'Baremaps': 'https://github.com/apache/baremaps',
#  'Cloudberry': 'https://github.com/apache/cloudberry/',
#  'DevLake': 'https://github.com/apache/incubator-devlake',
#  'Fury': 'https://github.com/apache/incubator-fury',
#  'Gluten': 'https://github.com/apache/incubator-gluten',
#  'Grails': 'https://github.com/grails/grails-core',
#  'GraphAr': 'https://github.com/apache/incubator-graphar',
#  'Gravitino': 'https://github.com/apache/gravitino',
#  'HertzBeat': 'https://github.com/apache/hertzbeat',
#  'HoraeDB': 'https://github.com/apache/incubator-horaedb',
#  'HugeGraph': 'https://github.com/apache/hugegraph',
#  'Iggy': 'https://github.com/iggy-rs/iggy',
#  'KIE': 'https://github.com/apache/incubator-kie-issues',
#  'Livy': 'https://github.com/apache/incubator-livy',
#  'Nemo': 'https://github.com/apache/incubator-nemo',
#  'NLPCraft': 'https://github.com/apache/incubator-nlpcraft',
#  'OpenServerless': 'https://github.com/apache/openserverless',
#  'Otava': 'https://github.com/apache/hunter',
#  'OzHera': 'https://github.com/apache/ozhera',
#  'Pegasus': 'https://github.com/apache/incubator-pegasus',
#  'Polaris': 'https://github.com/apache/polaris',
#  'Pony Mail': 'https://github.com/apache/incubator-ponymail',
#  'ResilientDB': 'https://github.com/apache/incubator-resilientdb',
#  'Seata': 'https://github.com/apache/incubator-seata',
#  'StormCrawler': 'https://github.com/apache/incubator-stormcrawler',
#  'Teaclave': 'https://github.com/apache/incubator-teaclave',
#  'Toree': 'https://github.com/apache/incubator-toree',
#  'Training': 'https://github.com/apache/incubator-training',
#  'Wayang': 'https://github.com/apache/incubator-wayang',
#  'XTable': 'https://github.com/apache/incubator-xtable',
#  'Uniffle': 'https://github.com/apache/incubator-uniffle'}

# %%
import requests
import json
import time
from config import GITHUB_TOKEN

HEADERS = {"Accept": "application/vnd.github.v3+json"}

def get_repo_stats(repo_url, github_token=None):
    if "github.com" not in repo_url:
        return {"stars": None, "forks": None, "pull_requests": None, "error": "Invalid URL"}

    parts = repo_url.replace("https://github.com/", "").strip("/").split("/")
    if len(parts) < 2:
        return {"stars": None, "forks": None, "pull_requests": None, "error": "Invalid repo format"}

    owner, repo = parts[:2]
    repo_api_url = f"https://api.github.com/repos/{owner}/{repo}"
    pr_api_url = f"https://api.github.com/repos/{owner}/{repo}/pulls?state=all"

    headers = HEADERS.copy()
    if github_token:
        headers["Authorization"] = f"Bearer {GITHUB_TOKEN}"

    repo_response = requests.get(repo_api_url, headers=headers)
    pr_response = requests.get(pr_api_url, headers=headers)

    if repo_response.status_code == 200 and pr_response.status_code == 200:
        repo_data = repo_response.json()
        pr_data = pr_response.json()
        pr_count = len(pr_data)

        stars = repo_data.get("stargazers_count", 0)
        forks = repo_data.get("forks_count", 0)

        pScore = stars + forks + (pr_count ** 2)

        return {"stars": stars, "forks": forks, "pull_requests": pr_count, "pScore": pScore}
    elif repo_response.status_code == 403 or pr_response.status_code == 403:
        return {"error": "Rate limit exceeded! Try again later or use a valid token."}
    else:
        return {"stars": None, "forks": None, "pull_requests": None, 
                "error": f"Failed to fetch data (Status {repo_response.status_code} / {pr_response.status_code})"}

def fetch_podling_data(podlings, github_token=None):
    podling_data = {}

    for podling, repo_url in podlings.items():
        podling_data[podling] = get_repo_stats(repo_url, github_token)
        print(f"Fetched: {podling} -> {podling_data[podling]}")
        time.sleep(1)

    with open("podling_github_stats.json", "w") as f:
        json.dump(podling_data, f, indent=4)

    return podling_data

scraped_data = fetch_podling_data(github_urls, github_token=GITHUB_TOKEN)
# Out:
# Fetched: Amoro -> {'stars': 931, 'forks': 315, 'pull_requests': 30, 'pScore': 2146}
# Fetched: Annotator -> {'stars': 231, 'forks': 41, 'pull_requests': 30, 'pScore': 1172}
# Fetched: Baremaps -> {'stars': 531, 'forks': 66, 'pull_requests': 30, 'pScore': 1497}
# Fetched: Cloudberry -> {'stars': 902, 'forks': 138, 'pull_requests': 30, 'pScore': 1940}
# Fetched: DevLake -> {'stars': 2671, 'forks': 557, 'pull_requests': 30, 'pScore': 4128}
# Fetched: Fury -> {'stars': 3229, 'forks': 265, 'pull_requests': 30, 'pScore': 4394}
# Fetched: Gluten -> {'stars': 1288, 'forks': 466, 'pull_requests': 30, 'pScore': 2654}
# Fetched: Grails -> {'stars': 2795, 'forks': 953, 'pull_requests': 30, 'pScore': 4648}
# Fetched: GraphAr -> {'stars': 234, 'forks': 46, 'pull_requests': 30, 'pScore': 1180}
# Fetched: Gravitino -> {'stars': 1372, 'forks': 415, 'pull_requests': 30, 'pScore': 2687}
# Fetched: HertzBeat -> {'stars': 6047, 'forks': 1064, 'pull_requests': 30, 'pScore': 8011}
# Fetched: HoraeDB -> {'stars': 2713, 'forks': 212, 'pull_requests': 30, 'pScore': 3825}
# Fetched: HugeGraph -> {'stars': 2707, 'forks': 528, 'pull_requests': 30, 'pScore': 4135}
# Fetched: Iggy -> {'stars': 2347, 'forks': 121, 'pull_requests': 30, 'pScore': 3368}
# Fetched: KIE -> {'stars': 12, 'forks': 1, 'pull_requests': 1, 'pScore': 14}
# Fetched: Livy -> {'stars': 904, 'forks': 606, 'pull_requests': 30, 'pScore': 2410}
# Fetched: Nemo -> {'stars': 112, 'forks': 64, 'pull_requests': 30, 'pScore': 1076}
# Fetched: NLPCraft -> {'stars': 79, 'forks': 25, 'pull_requests': 30, 'pScore': 1004}
# Fetched: OpenServerless -> {'stars': 536, 'forks': 15, 'pull_requests': 26, 'pScore': 1227}
# Fetched: Otava -> {'stars': 58, 'forks': 12, 'pull_requests': 26, 'pScore': 746}
# Fetched: OzHera -> {'stars': 91, 'forks': 35, 'pull_requests': 30, 'pScore': 1026}
# Fetched: Pegasus -> {'stars': 2002, 'forks': 311, 'pull_requests': 30, 'pScore': 3213}
# Fetched: Polaris -> {'stars': 1376, 'forks': 200, 'pull_requests': 30, 'pScore': 2476}
# Fetched: Pony Mail -> {'stars': 81, 'forks': 31, 'pull_requests': 30, 'pScore': 1012}
# Fetched: ResilientDB -> {'stars': 145, 'forks': 214, 'pull_requests': 30, 'pScore': 1259}
# Fetched: Seata -> {'stars': 25529, 'forks': 8811, 'pull_requests': 30, 'pScore': 35240}
# Fetched: StormCrawler -> {'stars': 901, 'forks': 262, 'pull_requests': 30, 'pScore': 2063}
# Fetched: Teaclave -> {'stars': 773, 'forks': 160, 'pull_requests': 30, 'pScore': 1833}
# Fetched: Toree -> {'stars': 741, 'forks': 224, 'pull_requests': 30, 'pScore': 1865}
# Fetched: Training -> {'stars': 31, 'forks': 38, 'pull_requests': 30, 'pScore': 969}
# Fetched: Wayang -> {'stars': 218, 'forks': 91, 'pull_requests': 30, 'pScore': 1209}
# Fetched: XTable -> {'stars': 996, 'forks': 165, 'pull_requests': 30, 'pScore': 2061}
# Fetched: Uniffle -> {'stars': 402, 'forks': 154, 'pull_requests': 30, 'pScore': 1456}

# %%
df_target = pd.DataFrame(scraped_data)
display(df_target)
# Out:
#                Amoro  Annotator  Baremaps  Cloudberry  DevLake  Fury  Gluten  \
# stars            931        231       531         902     2671  3229    1288
# forks            315         41        66         138      557   265     466
# pull_requests     30         30        30          30       30    30      30
# pScore          2146       1172      1497        1940     4128  4394    2654
#
#                Grails  GraphAr  Gravitino  ...  Pony Mail  ResilientDB  Seata  \
# stars            2795      234       1372  ...         81          145  25529
# forks             953       46        415  ...         31          214   8811
# pull_requests      30       30         30  ...         30           30     30
# pScore           4648     1180       2687  ...       1012         1259  35240
#
#                StormCrawler  Teaclave  Toree  Training  Wayang  XTable  \
# stars                   901       773    741        31     218     996
# forks                   262       160    224        38      91     165
# pull_requests            30        30     30        30      30      30
# pScore                 2063      1833   1865       969    1209    2061
#
#                Uniffle
# stars              402
# forks              154
# pull_requests       30
# pScore            1456
#
# [4 rows x 33 columns]

# %%
df_target_transposed = df_target.T.reset_index()
df_target_transposed.rename(columns={'index': 'Podling'}, inplace=True)
df_merged = df.merge(df_target_transposed, on='Podling', how='inner')
display(df_merged)
df_merged_sorted = df_merged.sort_values(by="pScore", ascending=False).reset_index(drop=True)
df_merged_sorted["Popular"] = [1 if i < 17 else 0 for i in range(len(df_merged_sorted))]
display(df_merged_sorted)
df_merged_sorted.to_csv('rq3-dataset.csv', index=False)
# Out:
#            Podling    Sponsor  start_date elapsed_days reporting_monthly  \
# 0            Amoro  Incubator  2024-03-11          364             False
# 1        Annotator  Incubator  2016-08-30         3114             False
# 2         Baremaps  Incubator  2022-10-10          882             False
# 3       Cloudberry  Incubator  2024-10-11          150             False
# 4          DevLake  Incubator  2022-04-29         1046             False
# 5             Fury  Incubator  2023-12-15          451             False
# 6           Gluten  Incubator  2024-01-11          424             False
# 7           Grails     Groovy  2025-01-25           44             False
# 8          GraphAr  Incubator  2024-03-25          350             False
# 9        Gravitino  Incubator  2024-06-04          279              True
# 10       HertzBeat  Incubator  2024-04-05          339             False
# 11         HoraeDB  Incubator  2023-12-11          455             False
# 12       HugeGraph  Incubator  2022-01-23         1142             False
# 13            Iggy  Incubator  2025-02-04           34              True
# 14             KIE  Incubator  2023-01-13          787             False
# 15            Livy  Incubator  2017-06-05         2835             False
# 16            Nemo  Incubator  2018-02-04         2591              True
# 17        NLPCraft  Incubator  2020-02-13         1852             False
# 18  OpenServerless  Incubator  2024-06-17          266             False
# 19           Otava  Incubator  2024-11-27          103             False
# 20          OzHera  Incubator  2024-07-11          242             False
# 21         Pegasus  Incubator  2020-06-28         1716             False
# 22         Polaris  Incubator  2024-08-09          213             False
# 23       Pony Mail  Incubator  2016-05-27         3209              True
# 24     ResilientDB  Incubator  2023-10-21          506             False
# 25           Seata             2023-10-29          498             False
# 26    StormCrawler  Incubator  2024-03-19          356             False
# 27        Teaclave  Incubator  2019-08-20         2029              True
# 28           Toree  Incubator  2015-12-02         3386              True
# 29        Training  Incubator  2019-02-21         2209              True
# 30          Wayang  Incubator  2020-12-16         1545             False
# 31          XTable  Incubator  2024-02-11          393             False
#
#    reporting_group has_status_file status_update_date status_age  \
# 0                1            True         2024-03-19        356
# 1                1            True         2020-10-09       1613
# 2                3            True         2022-10-20        872
# 3                2            True         2024-12-05         95
# 4                2            True         2022-05-12       1033
# 5                2            True         2023-12-16        450
# 6                1            True         2024-01-15        420
# 7                1            True         2025-03-10          0
# 8                2            True         2024-04-07        337
# 9                3           False                             0
# 10               1            True         2024-04-11        333
# 11               2            True         2023-12-16        450
# 12               1            True         2024-12-13         87
# 13               3            True         2025-03-07          3
# 14               3            True         2024-02-13        391
# 15               1            True         2017-06-23       2817
# 16               3            True         2018-03-01       2566
# 17               2            True         2020-10-08       1614
# 18               3            True         2024-07-20        233
# 19               3            True         2025-02-21         17
# 20               3           False                             0
# 21               1            True         2023-12-20        446
# 22               3            True         2024-08-27        195
# 23               1            True         2024-07-19        234
# 24               1            True         2024-04-11        333
# 25               2            True         2023-12-02        464
# 26               1            True         2024-03-29        346
# 27               1            True         2023-04-04        706
# 28               2            True         2020-07-19       1695
# 29               2            True         2019-02-28       2202
# 30               3            True         2021-01-22       1508
# 31               2            True         2024-05-16        298
#
#    status_update_counts  ... has_a_dev_mailing_list  \
# 0                 0,0,0  ...                   True
# 1                 0,0,0  ...                  False
# 2                 0,0,0  ...                   True
# 3                 0,1,4  ...                   True
# 4                 0,0,0  ...                   True
# 5                 0,0,0  ...                   True
# 6                 0,0,0  ...                   True
# 7                 4,-,-  ...                   True
# 8                 0,0,0  ...                   True
# 9                        ...                  False
# 10                0,0,0  ...                   True
# 11                0,0,0  ...                   True
# 12                0,1,1  ...                   True
# 13                3,-,-  ...                   True
# 14                0,0,0  ...                   True
# 15                0,0,0  ...                  False
# 16                0,0,0  ...                   True
# 17                0,0,0  ...                  False
# 18                0,0,2  ...                   True
# 19                2,4,-  ...                   True
# 20                       ...                  False
# 21                0,0,0  ...                   True
# 22                0,0,1  ...                   True
# 23                0,0,1  ...                   True
# 24                0,0,0  ...                   True
# 25                0,0,0  ...                   True
# 26                0,0,0  ...                   True
# 27                0,0,0  ...                  False
# 28                0,0,0  ...                  False
# 29                0,0,0  ...                   True
# 30                0,0,0  ...                   True
# 31                0,0,0  ...                   True
#
#    has_a_commits_mailing_list has_website has_distribution_area  \
# 0                        True        True                  True
# 1                       False        True                  True
# 2                        True        True                  True
# 3                        True        True                 False
# 4                        True        True                  True
# 5                        True        True                  True
# 6                        True        True                  True
# 7                        True       False                 False
# 8                        True        True                  True
# 9                       False        True                  True
# 10                       True        True                  True
# 11                       True        True                  True
# 12                      False        True                  True
# 13                       True        True                 False
# 14                       True        True                  True
# 15                      False        True                  True
# 16                       True        True                  True
# 17                      False        True                  True
# 18                       True        True                 False
# 19                       True       False                 False
# 20                      False        True                  True
# 21                       True        True                  True
# 22                       True        True                  True
# 23                       True        True                  True
# 24                      False        True                  True
# 25                       True        True                  True
# 26                       True        True                  True
# 27                      False        True                  True
# 28                      False        True                  True
# 29                       True        True                  True
# 30                       True        True                  True
# 31                       True        True                  True
#
#    has_release_signing_keys has_release_distribution_area  stars forks  \
# 0                      True                          True    931   315
# 1                      True                          True    231    41
# 2                      True                          True    531    66
# 3                     False                         False    902   138
# 4                      True                          True   2671   557
# 5                      True                          True   3229   265
# 6                      True                          True   1288   466
# 7                     False                         False   2795   953
# 8                      True                          True    234    46
# 9                      True                          True   1372   415
# 10                     True                          True   6047  1064
# 11                     True                          True   2713   212
# 12                     True                          True   2707   528
# 13                    False                         False   2347   121
# 14                     True                          True     12     1
# 15                     True                          True    904   606
# 16                     True                          True    112    64
# 17                     True                          True     79    25
# 18                    False                         False    536    15
# 19                    False                         False     58    12
# 20                     True                         False     91    35
# 21                     True                          True   2002   311
# 22                     True                          True   1376   200
# 23                     True                          True     81    31
# 24                     True                          True    145   214
# 25                     True                          True  25529  8811
# 26                     True                          True    901   262
# 27                     True                          True    773   160
# 28                     True                          True    741   224
# 29                     True                          True     31    38
# 30                     True                          True    218    91
# 31                     True                          True    996   165
#
#    pull_requests pScore
# 0             30   2146
# 1             30   1172
# 2             30   1497
# 3             30   1940
# 4             30   4128
# 5             30   4394
# 6             30   2654
# 7             30   4648
# 8             30   1180
# 9             30   2687
# 10            30   8011
# 11            30   3825
# 12            30   4135
# 13            30   3368
# 14             1     14
# 15            30   2410
# 16            30   1076
# 17            30   1004
# 18            26   1227
# 19            26    746
# 20            30   1026
# 21            30   3213
# 22            30   2476
# 23            30   1012
# 24            30   1259
# 25            30  35240
# 26            30   2063
# 27            30   1833
# 28            30   1865
# 29            30    969
# 30            30   1209
# 31            30   2061
#
# [32 rows x 24 columns]
#            Podling    Sponsor  start_date elapsed_days reporting_monthly  \
# 0            Seata             2023-10-29          498             False
# 1        HertzBeat  Incubator  2024-04-05          339             False
# 2           Grails     Groovy  2025-01-25           44             False
# 3             Fury  Incubator  2023-12-15          451             False
# 4        HugeGraph  Incubator  2022-01-23         1142             False
# 5          DevLake  Incubator  2022-04-29         1046             False
# 6          HoraeDB  Incubator  2023-12-11          455             False
# 7             Iggy  Incubator  2025-02-04           34              True
# 8          Pegasus  Incubator  2020-06-28         1716             False
# 9        Gravitino  Incubator  2024-06-04          279              True
# 10          Gluten  Incubator  2024-01-11          424             False
# 11         Polaris  Incubator  2024-08-09          213             False
# 12            Livy  Incubator  2017-06-05         2835             False
# 13           Amoro  Incubator  2024-03-11          364             False
# 14    StormCrawler  Incubator  2024-03-19          356             False
# 15          XTable  Incubator  2024-02-11          393             False
# 16      Cloudberry  Incubator  2024-10-11          150             False
# 17           Toree  Incubator  2015-12-02         3386              True
# 18        Teaclave  Incubator  2019-08-20         2029              True
# 19        Baremaps  Incubator  2022-10-10          882             False
# 20     ResilientDB  Incubator  2023-10-21          506             False
# 21  OpenServerless  Incubator  2024-06-17          266             False
# 22          Wayang  Incubator  2020-12-16         1545             False
# 23         GraphAr  Incubator  2024-03-25          350             False
# 24       Annotator  Incubator  2016-08-30         3114             False
# 25            Nemo  Incubator  2018-02-04         2591              True
# 26          OzHera  Incubator  2024-07-11          242             False
# 27       Pony Mail  Incubator  2016-05-27         3209              True
# 28        NLPCraft  Incubator  2020-02-13         1852             False
# 29        Training  Incubator  2019-02-21         2209              True
# 30           Otava  Incubator  2024-11-27          103             False
# 31             KIE  Incubator  2023-01-13          787             False
#
#    reporting_group has_status_file status_update_date status_age  \
# 0                2            True         2023-12-02        464
# 1                1            True         2024-04-11        333
# 2                1            True         2025-03-10          0
# 3                2            True         2023-12-16        450
# 4                1            True         2024-12-13         87
# 5                2            True         2022-05-12       1033
# 6                2            True         2023-12-16        450
# 7                3            True         2025-03-07          3
# 8                1            True         2023-12-20        446
# 9                3           False                             0
# 10               1            True         2024-01-15        420
# 11               3            True         2024-08-27        195
# 12               1            True         2017-06-23       2817
# 13               1            True         2024-03-19        356
# 14               1            True         2024-03-29        346
# 15               2            True         2024-05-16        298
# 16               2            True         2024-12-05         95
# 17               2            True         2020-07-19       1695
# 18               1            True         2023-04-04        706
# 19               3            True         2022-10-20        872
# 20               1            True         2024-04-11        333
# 21               3            True         2024-07-20        233
# 22               3            True         2021-01-22       1508
# 23               2            True         2024-04-07        337
# 24               1            True         2020-10-09       1613
# 25               3            True         2018-03-01       2566
# 26               3           False                             0
# 27               1            True         2024-07-19        234
# 28               2            True         2020-10-08       1614
# 29               2            True         2019-02-28       2202
# 30               3            True         2025-02-21         17
# 31               3            True         2024-02-13        391
#
#    status_update_counts  ... has_a_commits_mailing_list has_website  \
# 0                 0,0,0  ...                       True        True
# 1                 0,0,0  ...                       True        True
# 2                 4,-,-  ...                       True       False
# 3                 0,0,0  ...                       True        True
# 4                 0,1,1  ...                      False        True
# 5                 0,0,0  ...                       True        True
# 6                 0,0,0  ...                       True        True
# 7                 3,-,-  ...                       True        True
# 8                 0,0,0  ...                       True        True
# 9                        ...                      False        True
# 10                0,0,0  ...                       True        True
# 11                0,0,1  ...                       True        True
# 12                0,0,0  ...                      False        True
# 13                0,0,0  ...                       True        True
# 14                0,0,0  ...                       True        True
# 15                0,0,0  ...                       True        True
# 16                0,1,4  ...                       True        True
# 17                0,0,0  ...                      False        True
# 18                0,0,0  ...                      False        True
# 19                0,0,0  ...                       True        True
# 20                0,0,0  ...                      False        True
# 21                0,0,2  ...                       True        True
# 22                0,0,0  ...                       True        True
# 23                0,0,0  ...                       True        True
# 24                0,0,0  ...                      False        True
# 25                0,0,0  ...                       True        True
# 26                       ...                      False        True
# 27                0,0,1  ...                       True        True
# 28                0,0,0  ...                      False        True
# 29                0,0,0  ...                       True        True
# 30                2,4,-  ...                       True       False
# 31                0,0,0  ...                       True        True
#
#    has_distribution_area has_release_signing_keys  \
# 0                   True                     True
# 1                   True                     True
# 2                  False                    False
# 3                   True                     True
# 4                   True                     True
# 5                   True                     True
# 6                   True                     True
# 7                  False                    False
# 8                   True                     True
# 9                   True                     True
# 10                  True                     True
# 11                  True                     True
# 12                  True                     True
# 13                  True                     True
# 14                  True                     True
# 15                  True                     True
# 16                 False                    False
# 17                  True                     True
# 18                  True                     True
# 19                  True                     True
# 20                  True                     True
# 21                 False                    False
# 22                  True                     True
# 23                  True                     True
# 24                  True                     True
# 25                  True                     True
# 26                  True                     True
# 27                  True                     True
# 28                  True                     True
# 29                  True                     True
# 30                 False                    False
# 31                  True                     True
#
#    has_release_distribution_area  stars forks pull_requests pScore Popular
# 0                           True  25529  8811            30  35240       1
# 1                           True   6047  1064            30   8011       1
# 2                          False   2795   953            30   4648       1
# 3                           True   3229   265            30   4394       1
# 4                           True   2707   528            30   4135       1
# 5                           True   2671   557            30   4128       1
# 6                           True   2713   212            30   3825       1
# 7                          False   2347   121            30   3368       1
# 8                           True   2002   311            30   3213       1
# 9                           True   1372   415            30   2687       1
# 10                          True   1288   466            30   2654       1
# 11                          True   1376   200            30   2476       1
# 12                          True    904   606            30   2410       1
# 13                          True    931   315            30   2146       1
# 14                          True    901   262            30   2063       1
# 15                          True    996   165            30   2061       1
# 16                         False    902   138            30   1940       1
# 17                          True    741   224            30   1865       0
# 18                          True    773   160            30   1833       0
# 19                          True    531    66            30   1497       0
# 20                          True    145   214            30   1259       0
# 21                         False    536    15            26   1227       0
# 22                          True    218    91            30   1209       0
# 23                          True    234    46            30   1180       0
# 24                          True    231    41            30   1172       0
# 25                          True    112    64            30   1076       0
# 26                         False     91    35            30   1026       0
# 27                          True     81    31            30   1012       0
# 28                          True     79    25            30   1004       0
# 29                          True     31    38            30    969       0
# 30                         False     58    12            26    746       0
# 31                          True     12     1             1     14       0
#
# [32 rows x 25 columns]
