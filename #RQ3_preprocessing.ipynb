# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd


url = "https://incubator.apache.org/clutch/"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")
rows = soup.find_all('tr')

data_list = []
for row in rows[1:]:
    cols = row.find_all('td')
    data = {
        "Podling": cols[0].get_text(strip=True),
        "Sponsor": cols[1].get_text(strip=True),
        "start_date": cols[2].get_text(strip=True),
        "elapsed_days": cols[3].get_text(strip=True),
        "reporting_monthly": cols[4].get_text(strip=True),
        "reporting_group": cols[5].get_text(strip=True),
        "has_status_file": cols[6].get_text(strip=True),
        "status_update_date": cols[7].get_text(strip=True),
        "status_age": cols[8].get_text(strip=True),
        "status_update_counts": cols[9].get_text(strip=True),
        "no_of_committers": cols[10].get_text(strip=True),
        "no_of_new_committers": cols[11].get_text(strip=True),
        "has_a_code_repo": cols[12].get_text(strip=True),
        "has_issue_tracker": cols[13].get_text(strip=True),
        "has_a_dev_mailing_list": cols[14].get_text(strip=True),
        "has_a_commits_mailing_list": cols[15].get_text(strip=True),
        "has_website": cols[16].get_text(strip=True),
        "has_distribution_area": cols[17].get_text(strip=True),
        "has_release_signing_keys": cols[18].get_text(strip=True),
        "has_release_distribution_area": cols[19].get_text(strip=True),
    }
    data_list.append(data)

df = pd.DataFrame(data_list)
df = df.iloc[:-1]  # Remove the last row
display(df)
# Out:
# /Users/haseebrahman/Desktop/Projects/SEProject-Team4-The-Popularity-Paradigm/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
#            Podling    Sponsor  start_date elapsed_days reporting_monthly  \
# 0            Amoro  Incubator  2024-03-11          362             False
# 1        Annotator  Incubator  2016-08-30         3112             False
# 2         Baremaps  Incubator  2022-10-10          880             False
# 3       Cloudberry  Incubator  2024-10-11          148             False
# 4          DevLake  Incubator  2022-04-29         1044             False
# 5             Fury  Incubator  2023-12-15          449             False
# 6           Gluten  Incubator  2024-01-11          422             False
# 7           Grails     Groovy  2025-01-25           42             False
# 8          GraphAr  Incubator  2024-03-25          348             False
# 9        Gravitino  Incubator  2024-06-04          277              True
# 10       HertzBeat  Incubator  2024-04-05          337             False
# 11         HoraeDB  Incubator  2023-12-11          453             False
# 12       HugeGraph  Incubator  2022-01-23         1140             False
# 13            Iggy  Incubator  2025-02-04           32              True
# 14             KIE  Incubator  2023-01-13          785             False
# 15            Livy  Incubator  2017-06-05         2833             False
# 16            Nemo  Incubator  2018-02-04         2589              True
# 17        NLPCraft  Incubator  2020-02-13         1850             False
# 18  OpenServerless  Incubator  2024-06-17          264             False
# 19           Otava  Incubator  2024-11-27          101             False
# 20          OzHera  Incubator  2024-07-11          240             False
# 21         Pegasus  Incubator  2020-06-28         1714             False
# 22         Polaris  Incubator  2024-08-09          211             False
# 23       Pony Mail  Incubator  2016-05-27         3207              True
# 24     ResilientDB  Incubator  2023-10-21          504             False
# 25           Seata             2023-10-29          496             False
# 26    StormCrawler  Incubator  2024-03-19          354             False
# 27        Teaclave  Incubator  2019-08-20         2027              True
# 28           Toree  Incubator  2015-12-02         3384              True
# 29        Training  Incubator  2019-02-21         2207              True
# 30         Uniffle  Incubator  2022-06-06         1006             False
# 31          Wayang  Incubator  2020-12-16         1543             False
# 32          XTable  Incubator  2024-02-11          391             False
#
#    reporting_group has_status_file status_update_date status_age  \
# 0                1            True         2024-03-19        354
# 1                1            True         2020-10-09       1611
# 2                3            True         2022-10-20        870
# 3                2            True         2024-12-05         93
# 4                2            True         2022-05-12       1031
# 5                2            True         2023-12-16        448
# 6                1            True         2024-01-15        418
# 7                1           False                             0
# 8                2            True         2024-04-07        335
# 9                3           False                             0
# 10               1            True         2024-04-11        331
# 11               2            True         2023-12-16        448
# 12               1            True         2024-12-13         85
# 13               2            True         2025-03-07          1
# 14               3            True         2024-02-13        389
# 15               1            True         2017-06-23       2815
# 16               3            True         2018-03-01       2564
# 17               2            True         2020-10-08       1612
# 18               3            True         2024-07-20        231
# 19               3            True         2025-02-21         15
# 20               3           False                             0
# 21               1            True         2023-12-20        444
# 22               3            True         2024-08-27        193
# 23               1            True         2024-07-19        232
# 24               1            True         2024-04-11        331
# 25               2            True         2023-12-02        462
# 26               1            True         2024-03-29        344
# 27               1            True         2023-04-04        704
# 28               2            True         2020-07-19       1693
# 29               2            True         2019-02-28       2200
# 30               3            True         2022-10-24        866
# 31               3            True         2021-01-22       1506
# 32               2            True         2024-05-16        296
#
#    status_update_counts no_of_committers no_of_new_committers has_a_code_repo  \
# 0                 0,0,0               24                    0            True
# 1                 0,0,0                8                    0            True
# 2                 0,0,0               14                    0            True
# 3                 0,1,4               24                    0            True
# 4                 0,0,0               34                    0            True
# 5                 0,0,0               12                    0            True
# 6                 0,0,0               37                    0            True
# 7                                      9                    0           False
# 8                 0,0,0               11                    0            True
# 9                                     25                    0            True
# 10                0,0,0               25                    0            True
# 11                0,0,0               15                    0            True
# 12                0,1,1               18                    6            True
# 13                3,-,-               12                    0            True
# 14                0,0,0               64                    0            True
# 15                0,0,0               24                    0            True
# 16                0,0,0               18                    0            True
# 17                0,0,0               10                    1            True
# 18                0,0,2               13                    0            True
# 19                2,4,-                9                    1            True
# 20                                    13                    0            True
# 21                0,0,0               19                    5            True
# 22                0,0,1               21                    0            True
# 23                0,0,1               11                    0            True
# 24                0,0,0               31                    0            True
# 25                0,0,0               30                    0            True
# 26                0,0,0               10                    0            True
# 27                0,0,0               25                    3            True
# 28                0,0,0               11                    3            True
# 29                0,0,0               17                    0            True
# 30                0,0,0               22                    1            True
# 31                0,0,0               16                    0            True
# 32                0,0,0               10                    0            True
#
#    has_issue_tracker has_a_dev_mailing_list has_a_commits_mailing_list  \
# 0               True                   True                       True
# 1               True                  False                      False
# 2               True                   True                       True
# 3              False                   True                       True
# 4               True                   True                       True
# 5               True                   True                       True
# 6               True                   True                       True
# 7              False                  False                      False
# 8               True                   True                       True
# 9              False                  False                      False
# 10              True                   True                       True
# 11              True                   True                       True
# 12              True                   True                      False
# 13              True                   True                       True
# 14              True                   True                       True
# 15             False                  False                      False
# 16              True                   True                       True
# 17             False                  False                      False
# 18              True                   True                       True
# 19             False                   True                       True
# 20             False                  False                      False
# 21              True                   True                       True
# 22              True                   True                       True
# 23              True                   True                       True
# 24             False                   True                      False
# 25              True                   True                       True
# 26              True                   True                       True
# 27             False                  False                      False
# 28              True                  False                      False
# 29              True                   True                       True
# 30             False                   True                       True
# 31             False                   True                       True
# 32              True                   True                       True
#
#    has_website has_distribution_area has_release_signing_keys  \
# 0         True                  True                     True
# 1         True                  True                     True
# 2         True                  True                     True
# 3         True                 False                    False
# 4         True                  True                     True
# 5         True                  True                     True
# 6         True                  True                     True
# 7        False                 False                    False
# 8         True                  True                     True
# 9         True                  True                     True
# 10        True                  True                     True
# 11        True                  True                     True
# 12        True                  True                     True
# 13        True                 False                    False
# 14        True                  True                     True
# 15        True                  True                     True
# 16        True                  True                     True
# 17        True                  True                     True
# 18        True                 False                    False
# 19       False                 False                    False
# 20        True                  True                     True
# 21        True                  True                     True
# 22        True                  True                     True
# 23        True                  True                     True
# 24        True                  True                     True
# 25        True                  True                     True
# 26        True                  True                     True
# 27        True                  True                     True
# 28        True                  True                     True
# 29        True                  True                     True
# 30        True                  True                     True
# 31        True                  True                     True
# 32        True                  True                     True
#
#    has_release_distribution_area
# 0                           True
# 1                           True
# 2                           True
# 3                          False
# 4                           True
# 5                           True
# 6                           True
# 7                          False
# 8                           True
# 9                           True
# 10                          True
# 11                          True
# 12                          True
# 13                         False
# 14                          True
# 15                          True
# 16                          True
# 17                          True
# 18                         False
# 19                         False
# 20                         False
# 21                          True
# 22                          True
# 23                          True
# 24                          True
# 25                          True
# 26                          True
# 27                          True
# 28                          True
# 29                          True
# 30                          True
# 31                          True
# 32                          True

# %%
import requests
import lxml.html as lx
import time
import json

podling_names = df['Podling'].tolist()
podlings = podling_names
BASE_URL = "https://incubator.apache.org/projects/"
HEADERS = {"User-Agent": "Mozilla/5.0"}

github_urls = {}
def get_github_url(podling):
    podling_url = f"{BASE_URL}{podling.lower()}.html"
    response = requests.get(podling_url, headers=HEADERS)

    if response.status_code == 200:
        tree = lx.fromstring(response.content)
        github_links = tree.xpath('//a[contains(@href, "github.com/apache")]/@href')

        if github_links:
            github_url = github_links[0]
            github_url = github_url.split("/issues")[0]
            return github_url
        else:
            return "GitHub URL not found"
    else:
        return "Page not found"

for podling in podlings:
    github_urls[podling] = get_github_url(podling)
    print(f"{podling}: {github_urls[podling]}")
    time.sleep(1)
# Out:
# Amoro: https://github.com/apache/incubator-amoro
# Annotator: GitHub URL not found
# Baremaps: https://github.com/apache/baremaps
# Cloudberry: https://github.com/apache/cloudberry/
# DevLake: https://github.com/apache/incubator-devlake
# Fury: https://github.com/apache/incubator-fury
# Gluten: GitHub URL not found
# Grails: Page not found
# GraphAr: https://github.com/apache/incubator-graphar
# Gravitino: Page not found
# HertzBeat: https://github.com/apache/hertzbeat
# HoraeDB: https://github.com/apache/incubator-horaedb
# HugeGraph: https://github.com/apache/hugegraph
# Iggy: https://github.com/apache/iggy
# KIE: https://github.com/apache/incubator-kie-issues
# Livy: GitHub URL not found
# Nemo: GitHub URL not found
# NLPCraft: GitHub URL not found
# OpenServerless: https://github.com/apache/openserverless
# Otava: https://github.com/apache/otava/
# OzHera: Page not found
# Pegasus: GitHub URL not found
# Polaris: https://github.com/apache/polaris
# Pony Mail: Page not found
# ResilientDB: GitHub URL not found
# Seata: https://github.com/apache/incubator-seata
# StormCrawler: https://github.com/apache/incubator-stormcrawler
# Teaclave: GitHub URL not found
# Toree: https://github.com/apache/incubator-toree
# Training: GitHub URL not found
# Uniffle: https://github.com/apache/uniffle
# Wayang: GitHub URL not found
# XTable: https://github.com/apache/incubator-xtable

# %%
# Handle edge cases of github url scraping
github_urls["Annotator"] = "https://github.com/apache/incubator-annotator"
github_urls["Gluten"] = "https://github.com/apache/incubator-gluten"
github_urls["Grails"] = "https://github.com/grails/grails-core"
github_urls["Gravitino"] = "https://github.com/apache/gravitino"
github_urls["Livy"] = "https://github.com/apache/incubator-livy"
github_urls["Nemo"] = "https://github.com/apache/incubator-nemo"
github_urls["NLPCraft"] = "https://github.com/apache/incubator-nlpcraft"
github_urls["OzHera"] = "https://github.com/apache/ozhera"
github_urls["Pegasus"] = "https://github.com/apache/incubator-pegasus"
github_urls["Pony Mail"] = "https://github.com/apache/incubator-ponymail"
github_urls["ResilientDB"] = "https://github.com/apache/incubator-resilientdb"
github_urls["Teaclave"] = "https://github.com/apache/incubator-teaclave"
github_urls["Training"] = "https://github.com/apache/incubator-training"
github_urls["Wayang"] = "https://github.com/apache/incubator-wayang"
github_urls["Otava"] = "https://github.com/apache/hunter"
github_urls["Uniffle"] = "https://github.com/apache/incubator-uniffle"
github_urls["Iggy"] = "https://github.com/iggy-rs/iggy"
display(github_urls)
# Out:
# {'Amoro': 'https://github.com/apache/incubator-amoro',
#  'Annotator': 'https://github.com/apache/incubator-annotator',
#  'Baremaps': 'https://github.com/apache/baremaps',
#  'Cloudberry': 'https://github.com/apache/cloudberry/',
#  'DevLake': 'https://github.com/apache/incubator-devlake',
#  'Fury': 'https://github.com/apache/incubator-fury',
#  'Gluten': 'https://github.com/apache/incubator-gluten',
#  'Grails': 'https://github.com/grails/grails-core',
#  'GraphAr': 'https://github.com/apache/incubator-graphar',
#  'Gravitino': 'https://github.com/apache/gravitino',
#  'HertzBeat': 'https://github.com/apache/hertzbeat',
#  'HoraeDB': 'https://github.com/apache/incubator-horaedb',
#  'HugeGraph': 'https://github.com/apache/hugegraph',
#  'Iggy': 'https://github.com/iggy-rs/iggy',
#  'KIE': 'https://github.com/apache/incubator-kie-issues',
#  'Livy': 'https://github.com/apache/incubator-livy',
#  'Nemo': 'https://github.com/apache/incubator-nemo',
#  'NLPCraft': 'https://github.com/apache/incubator-nlpcraft',
#  'OpenServerless': 'https://github.com/apache/openserverless',
#  'Otava': 'https://github.com/apache/hunter',
#  'OzHera': 'https://github.com/apache/ozhera',
#  'Pegasus': 'https://github.com/apache/incubator-pegasus',
#  'Polaris': 'https://github.com/apache/polaris',
#  'Pony Mail': 'https://github.com/apache/incubator-ponymail',
#  'ResilientDB': 'https://github.com/apache/incubator-resilientdb',
#  'Seata': 'https://github.com/apache/incubator-seata',
#  'StormCrawler': 'https://github.com/apache/incubator-stormcrawler',
#  'Teaclave': 'https://github.com/apache/incubator-teaclave',
#  'Toree': 'https://github.com/apache/incubator-toree',
#  'Training': 'https://github.com/apache/incubator-training',
#  'Uniffle': 'https://github.com/apache/incubator-uniffle',
#  'Wayang': 'https://github.com/apache/incubator-wayang',
#  'XTable': 'https://github.com/apache/incubator-xtable'}

# %%
import requests
import json
import time
from config import GITHUB_TOKEN

HEADERS = {"Accept": "application/vnd.github.v3+json"}

def get_repo_stats(repo_url, github_token=None):
    if "github.com" not in repo_url:
        return {"stars": None, "forks": None, "pull_requests": None, "error": "Invalid URL"}

    parts = repo_url.replace("https://github.com/", "").strip("/").split("/")
    if len(parts) < 2:
        return {"stars": None, "forks": None, "pull_requests": None, "error": "Invalid repo format"}

    owner, repo = parts[:2]
    repo_api_url = f"https://api.github.com/repos/{owner}/{repo}"
    pr_api_url = f"https://api.github.com/repos/{owner}/{repo}/pulls?state=all"

    headers = HEADERS.copy()
    if github_token:
        headers["Authorization"] = f"Bearer {GITHUB_TOKEN}"

    repo_response = requests.get(repo_api_url, headers=headers)
    pr_response = requests.get(pr_api_url, headers=headers)

    if repo_response.status_code == 200 and pr_response.status_code == 200:
        repo_data = repo_response.json()
        pr_data = pr_response.json()
        pr_count = len(pr_data)

        stars = repo_data.get("stargazers_count", 0)
        forks = repo_data.get("forks_count", 0)

        pScore = stars + forks + (pr_count ** 2)

        return {"stars": stars, "forks": forks, "pull_requests": pr_count, "pScore": pScore}
    elif repo_response.status_code == 403 or pr_response.status_code == 403:
        return {"error": "Rate limit exceeded! Try again later or use a valid token."}
    else:
        return {"stars": None, "forks": None, "pull_requests": None, 
                "error": f"Failed to fetch data (Status {repo_response.status_code} / {pr_response.status_code})"}

def fetch_podling_data(podlings, github_token=None):
    podling_data = {}

    for podling, repo_url in podlings.items():
        podling_data[podling] = get_repo_stats(repo_url, github_token)
        print(f"Fetched: {podling} -> {podling_data[podling]}")
        time.sleep(1)

    with open("podling_github_stats.json", "w") as f:
        json.dump(podling_data, f, indent=4)

    return podling_data

scraped_data = fetch_podling_data(github_urls, github_token=GITHUB_TOKEN)
# Out:
# Fetched: Amoro -> {'stars': 930, 'forks': 316, 'pull_requests': 30, 'pScore': 2146}
# Fetched: Annotator -> {'stars': 231, 'forks': 41, 'pull_requests': 30, 'pScore': 1172}
# Fetched: Baremaps -> {'stars': 531, 'forks': 67, 'pull_requests': 30, 'pScore': 1498}
# Fetched: Cloudberry -> {'stars': 902, 'forks': 138, 'pull_requests': 30, 'pScore': 1940}
# Fetched: DevLake -> {'stars': 2668, 'forks': 556, 'pull_requests': 30, 'pScore': 4124}
# Fetched: Fury -> {'stars': 3227, 'forks': 265, 'pull_requests': 30, 'pScore': 4392}
# Fetched: Gluten -> {'stars': 1286, 'forks': 466, 'pull_requests': 30, 'pScore': 2652}
# Fetched: Grails -> {'stars': 2794, 'forks': 953, 'pull_requests': 30, 'pScore': 4647}
# Fetched: GraphAr -> {'stars': 233, 'forks': 45, 'pull_requests': 30, 'pScore': 1178}
# Fetched: Gravitino -> {'stars': 1371, 'forks': 415, 'pull_requests': 30, 'pScore': 2686}
# Fetched: HertzBeat -> {'stars': 6039, 'forks': 1065, 'pull_requests': 30, 'pScore': 8004}
# Fetched: HoraeDB -> {'stars': 2712, 'forks': 211, 'pull_requests': 30, 'pScore': 3823}
# Fetched: HugeGraph -> {'stars': 2707, 'forks': 527, 'pull_requests': 30, 'pScore': 4134}
# Fetched: Iggy -> {'stars': 2347, 'forks': 121, 'pull_requests': 30, 'pScore': 3368}
# Fetched: KIE -> {'stars': 12, 'forks': 1, 'pull_requests': 1, 'pScore': 14}
# Fetched: Livy -> {'stars': 904, 'forks': 606, 'pull_requests': 30, 'pScore': 2410}
# Fetched: Nemo -> {'stars': 112, 'forks': 64, 'pull_requests': 30, 'pScore': 1076}
# Fetched: NLPCraft -> {'stars': 79, 'forks': 25, 'pull_requests': 30, 'pScore': 1004}
# Fetched: OpenServerless -> {'stars': 535, 'forks': 15, 'pull_requests': 26, 'pScore': 1226}
# Fetched: Otava -> {'stars': 58, 'forks': 12, 'pull_requests': 26, 'pScore': 746}
# Fetched: OzHera -> {'stars': 91, 'forks': 35, 'pull_requests': 30, 'pScore': 1026}
# Fetched: Pegasus -> {'stars': 2002, 'forks': 311, 'pull_requests': 30, 'pScore': 3213}
# Fetched: Polaris -> {'stars': 1371, 'forks': 199, 'pull_requests': 30, 'pScore': 2470}
# Fetched: Pony Mail -> {'stars': 80, 'forks': 31, 'pull_requests': 30, 'pScore': 1011}
# Fetched: ResilientDB -> {'stars': 145, 'forks': 214, 'pull_requests': 30, 'pScore': 1259}
# Fetched: Seata -> {'stars': 25521, 'forks': 8811, 'pull_requests': 30, 'pScore': 35232}
# Fetched: StormCrawler -> {'stars': 901, 'forks': 262, 'pull_requests': 30, 'pScore': 2063}
# Fetched: Teaclave -> {'stars': 773, 'forks': 160, 'pull_requests': 30, 'pScore': 1833}
# Fetched: Toree -> {'stars': 741, 'forks': 224, 'pull_requests': 30, 'pScore': 1865}
# Fetched: Training -> {'stars': 31, 'forks': 38, 'pull_requests': 30, 'pScore': 969}
# Fetched: Uniffle -> {'stars': 402, 'forks': 154, 'pull_requests': 30, 'pScore': 1456}
# Fetched: Wayang -> {'stars': 217, 'forks': 91, 'pull_requests': 30, 'pScore': 1208}
# Fetched: XTable -> {'stars': 994, 'forks': 164, 'pull_requests': 30, 'pScore': 2058}

# %%
df_target = pd.DataFrame(scraped_data)
display(df_target)
# Out:
#                Amoro  Annotator  Baremaps  Cloudberry  DevLake  Fury  Gluten  \
# stars            930        231       531         902     2668  3227    1286
# forks            316         41        67         138      556   265     466
# pull_requests     30         30        30          30       30    30      30
# pScore          2146       1172      1498        1940     4124  4392    2652
#
#                Grails  GraphAr  Gravitino  ...  Pony Mail  ResilientDB  Seata  \
# stars            2794      233       1371  ...         80          145  25521
# forks             953       45        415  ...         31          214   8811
# pull_requests      30       30         30  ...         30           30     30
# pScore           4647     1178       2686  ...       1011         1259  35232
#
#                StormCrawler  Teaclave  Toree  Training  Uniffle  Wayang  \
# stars                   901       773    741        31      402     217
# forks                   262       160    224        38      154      91
# pull_requests            30        30     30        30       30      30
# pScore                 2063      1833   1865       969     1456    1208
#
#                XTable
# stars             994
# forks             164
# pull_requests      30
# pScore           2058
#
# [4 rows x 33 columns]

# %%
df_target_transposed = df_target.T.reset_index()
df_target_transposed.rename(columns={'index': 'Podling'}, inplace=True)
df_merged = df.merge(df_target_transposed, on='Podling', how='inner')
display(df_merged)
df_merged_sorted = df_merged.sort_values(by="pScore", ascending=False).reset_index(drop=True)
df_merged_sorted["Popular"] = [1 if i < 17 else 0 for i in range(len(df_merged_sorted))]
display(df_merged_sorted)
df_merged_sorted.to_csv('rq3-dataset.csv', index=False)
# Out:
#            Podling    Sponsor  start_date elapsed_days reporting_monthly  \
# 0            Amoro  Incubator  2024-03-11          362             False
# 1        Annotator  Incubator  2016-08-30         3112             False
# 2         Baremaps  Incubator  2022-10-10          880             False
# 3       Cloudberry  Incubator  2024-10-11          148             False
# 4          DevLake  Incubator  2022-04-29         1044             False
# 5             Fury  Incubator  2023-12-15          449             False
# 6           Gluten  Incubator  2024-01-11          422             False
# 7           Grails     Groovy  2025-01-25           42             False
# 8          GraphAr  Incubator  2024-03-25          348             False
# 9        Gravitino  Incubator  2024-06-04          277              True
# 10       HertzBeat  Incubator  2024-04-05          337             False
# 11         HoraeDB  Incubator  2023-12-11          453             False
# 12       HugeGraph  Incubator  2022-01-23         1140             False
# 13            Iggy  Incubator  2025-02-04           32              True
# 14             KIE  Incubator  2023-01-13          785             False
# 15            Livy  Incubator  2017-06-05         2833             False
# 16            Nemo  Incubator  2018-02-04         2589              True
# 17        NLPCraft  Incubator  2020-02-13         1850             False
# 18  OpenServerless  Incubator  2024-06-17          264             False
# 19           Otava  Incubator  2024-11-27          101             False
# 20          OzHera  Incubator  2024-07-11          240             False
# 21         Pegasus  Incubator  2020-06-28         1714             False
# 22         Polaris  Incubator  2024-08-09          211             False
# 23       Pony Mail  Incubator  2016-05-27         3207              True
# 24     ResilientDB  Incubator  2023-10-21          504             False
# 25           Seata             2023-10-29          496             False
# 26    StormCrawler  Incubator  2024-03-19          354             False
# 27        Teaclave  Incubator  2019-08-20         2027              True
# 28           Toree  Incubator  2015-12-02         3384              True
# 29        Training  Incubator  2019-02-21         2207              True
# 30         Uniffle  Incubator  2022-06-06         1006             False
# 31          Wayang  Incubator  2020-12-16         1543             False
# 32          XTable  Incubator  2024-02-11          391             False
#
#    reporting_group has_status_file status_update_date status_age  \
# 0                1            True         2024-03-19        354
# 1                1            True         2020-10-09       1611
# 2                3            True         2022-10-20        870
# 3                2            True         2024-12-05         93
# 4                2            True         2022-05-12       1031
# 5                2            True         2023-12-16        448
# 6                1            True         2024-01-15        418
# 7                1           False                             0
# 8                2            True         2024-04-07        335
# 9                3           False                             0
# 10               1            True         2024-04-11        331
# 11               2            True         2023-12-16        448
# 12               1            True         2024-12-13         85
# 13               2            True         2025-03-07          1
# 14               3            True         2024-02-13        389
# 15               1            True         2017-06-23       2815
# 16               3            True         2018-03-01       2564
# 17               2            True         2020-10-08       1612
# 18               3            True         2024-07-20        231
# 19               3            True         2025-02-21         15
# 20               3           False                             0
# 21               1            True         2023-12-20        444
# 22               3            True         2024-08-27        193
# 23               1            True         2024-07-19        232
# 24               1            True         2024-04-11        331
# 25               2            True         2023-12-02        462
# 26               1            True         2024-03-29        344
# 27               1            True         2023-04-04        704
# 28               2            True         2020-07-19       1693
# 29               2            True         2019-02-28       2200
# 30               3            True         2022-10-24        866
# 31               3            True         2021-01-22       1506
# 32               2            True         2024-05-16        296
#
#    status_update_counts  ... has_a_dev_mailing_list  \
# 0                 0,0,0  ...                   True
# 1                 0,0,0  ...                  False
# 2                 0,0,0  ...                   True
# 3                 0,1,4  ...                   True
# 4                 0,0,0  ...                   True
# 5                 0,0,0  ...                   True
# 6                 0,0,0  ...                   True
# 7                        ...                  False
# 8                 0,0,0  ...                   True
# 9                        ...                  False
# 10                0,0,0  ...                   True
# 11                0,0,0  ...                   True
# 12                0,1,1  ...                   True
# 13                3,-,-  ...                   True
# 14                0,0,0  ...                   True
# 15                0,0,0  ...                  False
# 16                0,0,0  ...                   True
# 17                0,0,0  ...                  False
# 18                0,0,2  ...                   True
# 19                2,4,-  ...                   True
# 20                       ...                  False
# 21                0,0,0  ...                   True
# 22                0,0,1  ...                   True
# 23                0,0,1  ...                   True
# 24                0,0,0  ...                   True
# 25                0,0,0  ...                   True
# 26                0,0,0  ...                   True
# 27                0,0,0  ...                  False
# 28                0,0,0  ...                  False
# 29                0,0,0  ...                   True
# 30                0,0,0  ...                   True
# 31                0,0,0  ...                   True
# 32                0,0,0  ...                   True
#
#    has_a_commits_mailing_list has_website has_distribution_area  \
# 0                        True        True                  True
# 1                       False        True                  True
# 2                        True        True                  True
# 3                        True        True                 False
# 4                        True        True                  True
# 5                        True        True                  True
# 6                        True        True                  True
# 7                       False       False                 False
# 8                        True        True                  True
# 9                       False        True                  True
# 10                       True        True                  True
# 11                       True        True                  True
# 12                      False        True                  True
# 13                       True        True                 False
# 14                       True        True                  True
# 15                      False        True                  True
# 16                       True        True                  True
# 17                      False        True                  True
# 18                       True        True                 False
# 19                       True       False                 False
# 20                      False        True                  True
# 21                       True        True                  True
# 22                       True        True                  True
# 23                       True        True                  True
# 24                      False        True                  True
# 25                       True        True                  True
# 26                       True        True                  True
# 27                      False        True                  True
# 28                      False        True                  True
# 29                       True        True                  True
# 30                       True        True                  True
# 31                       True        True                  True
# 32                       True        True                  True
#
#    has_release_signing_keys has_release_distribution_area  stars forks  \
# 0                      True                          True    930   316
# 1                      True                          True    231    41
# 2                      True                          True    531    67
# 3                     False                         False    902   138
# 4                      True                          True   2668   556
# 5                      True                          True   3227   265
# 6                      True                          True   1286   466
# 7                     False                         False   2794   953
# 8                      True                          True    233    45
# 9                      True                          True   1371   415
# 10                     True                          True   6039  1065
# 11                     True                          True   2712   211
# 12                     True                          True   2707   527
# 13                    False                         False   2347   121
# 14                     True                          True     12     1
# 15                     True                          True    904   606
# 16                     True                          True    112    64
# 17                     True                          True     79    25
# 18                    False                         False    535    15
# 19                    False                         False     58    12
# 20                     True                         False     91    35
# 21                     True                          True   2002   311
# 22                     True                          True   1371   199
# 23                     True                          True     80    31
# 24                     True                          True    145   214
# 25                     True                          True  25521  8811
# 26                     True                          True    901   262
# 27                     True                          True    773   160
# 28                     True                          True    741   224
# 29                     True                          True     31    38
# 30                     True                          True    402   154
# 31                     True                          True    217    91
# 32                     True                          True    994   164
#
#    pull_requests pScore
# 0             30   2146
# 1             30   1172
# 2             30   1498
# 3             30   1940
# 4             30   4124
# 5             30   4392
# 6             30   2652
# 7             30   4647
# 8             30   1178
# 9             30   2686
# 10            30   8004
# 11            30   3823
# 12            30   4134
# 13            30   3368
# 14             1     14
# 15            30   2410
# 16            30   1076
# 17            30   1004
# 18            26   1226
# 19            26    746
# 20            30   1026
# 21            30   3213
# 22            30   2470
# 23            30   1011
# 24            30   1259
# 25            30  35232
# 26            30   2063
# 27            30   1833
# 28            30   1865
# 29            30    969
# 30            30   1456
# 31            30   1208
# 32            30   2058
#
# [33 rows x 24 columns]
#            Podling    Sponsor  start_date elapsed_days reporting_monthly  \
# 0            Seata             2023-10-29          496             False
# 1        HertzBeat  Incubator  2024-04-05          337             False
# 2           Grails     Groovy  2025-01-25           42             False
# 3             Fury  Incubator  2023-12-15          449             False
# 4        HugeGraph  Incubator  2022-01-23         1140             False
# 5          DevLake  Incubator  2022-04-29         1044             False
# 6          HoraeDB  Incubator  2023-12-11          453             False
# 7             Iggy  Incubator  2025-02-04           32              True
# 8          Pegasus  Incubator  2020-06-28         1714             False
# 9        Gravitino  Incubator  2024-06-04          277              True
# 10          Gluten  Incubator  2024-01-11          422             False
# 11         Polaris  Incubator  2024-08-09          211             False
# 12            Livy  Incubator  2017-06-05         2833             False
# 13           Amoro  Incubator  2024-03-11          362             False
# 14    StormCrawler  Incubator  2024-03-19          354             False
# 15          XTable  Incubator  2024-02-11          391             False
# 16      Cloudberry  Incubator  2024-10-11          148             False
# 17           Toree  Incubator  2015-12-02         3384              True
# 18        Teaclave  Incubator  2019-08-20         2027              True
# 19        Baremaps  Incubator  2022-10-10          880             False
# 20         Uniffle  Incubator  2022-06-06         1006             False
# 21     ResilientDB  Incubator  2023-10-21          504             False
# 22  OpenServerless  Incubator  2024-06-17          264             False
# 23          Wayang  Incubator  2020-12-16         1543             False
# 24         GraphAr  Incubator  2024-03-25          348             False
# 25       Annotator  Incubator  2016-08-30         3112             False
# 26            Nemo  Incubator  2018-02-04         2589              True
# 27          OzHera  Incubator  2024-07-11          240             False
# 28       Pony Mail  Incubator  2016-05-27         3207              True
# 29        NLPCraft  Incubator  2020-02-13         1850             False
# 30        Training  Incubator  2019-02-21         2207              True
# 31           Otava  Incubator  2024-11-27          101             False
# 32             KIE  Incubator  2023-01-13          785             False
#
#    reporting_group has_status_file status_update_date status_age  \
# 0                2            True         2023-12-02        462
# 1                1            True         2024-04-11        331
# 2                1           False                             0
# 3                2            True         2023-12-16        448
# 4                1            True         2024-12-13         85
# 5                2            True         2022-05-12       1031
# 6                2            True         2023-12-16        448
# 7                2            True         2025-03-07          1
# 8                1            True         2023-12-20        444
# 9                3           False                             0
# 10               1            True         2024-01-15        418
# 11               3            True         2024-08-27        193
# 12               1            True         2017-06-23       2815
# 13               1            True         2024-03-19        354
# 14               1            True         2024-03-29        344
# 15               2            True         2024-05-16        296
# 16               2            True         2024-12-05         93
# 17               2            True         2020-07-19       1693
# 18               1            True         2023-04-04        704
# 19               3            True         2022-10-20        870
# 20               3            True         2022-10-24        866
# 21               1            True         2024-04-11        331
# 22               3            True         2024-07-20        231
# 23               3            True         2021-01-22       1506
# 24               2            True         2024-04-07        335
# 25               1            True         2020-10-09       1611
# 26               3            True         2018-03-01       2564
# 27               3           False                             0
# 28               1            True         2024-07-19        232
# 29               2            True         2020-10-08       1612
# 30               2            True         2019-02-28       2200
# 31               3            True         2025-02-21         15
# 32               3            True         2024-02-13        389
#
#    status_update_counts  ... has_a_commits_mailing_list has_website  \
# 0                 0,0,0  ...                       True        True
# 1                 0,0,0  ...                       True        True
# 2                        ...                      False       False
# 3                 0,0,0  ...                       True        True
# 4                 0,1,1  ...                      False        True
# 5                 0,0,0  ...                       True        True
# 6                 0,0,0  ...                       True        True
# 7                 3,-,-  ...                       True        True
# 8                 0,0,0  ...                       True        True
# 9                        ...                      False        True
# 10                0,0,0  ...                       True        True
# 11                0,0,1  ...                       True        True
# 12                0,0,0  ...                      False        True
# 13                0,0,0  ...                       True        True
# 14                0,0,0  ...                       True        True
# 15                0,0,0  ...                       True        True
# 16                0,1,4  ...                       True        True
# 17                0,0,0  ...                      False        True
# 18                0,0,0  ...                      False        True
# 19                0,0,0  ...                       True        True
# 20                0,0,0  ...                       True        True
# 21                0,0,0  ...                      False        True
# 22                0,0,2  ...                       True        True
# 23                0,0,0  ...                       True        True
# 24                0,0,0  ...                       True        True
# 25                0,0,0  ...                      False        True
# 26                0,0,0  ...                       True        True
# 27                       ...                      False        True
# 28                0,0,1  ...                       True        True
# 29                0,0,0  ...                      False        True
# 30                0,0,0  ...                       True        True
# 31                2,4,-  ...                       True       False
# 32                0,0,0  ...                       True        True
#
#    has_distribution_area has_release_signing_keys  \
# 0                   True                     True
# 1                   True                     True
# 2                  False                    False
# 3                   True                     True
# 4                   True                     True
# 5                   True                     True
# 6                   True                     True
# 7                  False                    False
# 8                   True                     True
# 9                   True                     True
# 10                  True                     True
# 11                  True                     True
# 12                  True                     True
# 13                  True                     True
# 14                  True                     True
# 15                  True                     True
# 16                 False                    False
# 17                  True                     True
# 18                  True                     True
# 19                  True                     True
# 20                  True                     True
# 21                  True                     True
# 22                 False                    False
# 23                  True                     True
# 24                  True                     True
# 25                  True                     True
# 26                  True                     True
# 27                  True                     True
# 28                  True                     True
# 29                  True                     True
# 30                  True                     True
# 31                 False                    False
# 32                  True                     True
#
#    has_release_distribution_area  stars forks pull_requests pScore Popular
# 0                           True  25521  8811            30  35232       1
# 1                           True   6039  1065            30   8004       1
# 2                          False   2794   953            30   4647       1
# 3                           True   3227   265            30   4392       1
# 4                           True   2707   527            30   4134       1
# 5                           True   2668   556            30   4124       1
# 6                           True   2712   211            30   3823       1
# 7                          False   2347   121            30   3368       1
# 8                           True   2002   311            30   3213       1
# 9                           True   1371   415            30   2686       1
# 10                          True   1286   466            30   2652       1
# 11                          True   1371   199            30   2470       1
# 12                          True    904   606            30   2410       1
# 13                          True    930   316            30   2146       1
# 14                          True    901   262            30   2063       1
# 15                          True    994   164            30   2058       1
# 16                         False    902   138            30   1940       1
# 17                          True    741   224            30   1865       0
# 18                          True    773   160            30   1833       0
# 19                          True    531    67            30   1498       0
# 20                          True    402   154            30   1456       0
# 21                          True    145   214            30   1259       0
# 22                         False    535    15            26   1226       0
# 23                          True    217    91            30   1208       0
# 24                          True    233    45            30   1178       0
# 25                          True    231    41            30   1172       0
# 26                          True    112    64            30   1076       0
# 27                         False     91    35            30   1026       0
# 28                          True     80    31            30   1011       0
# 29                          True     79    25            30   1004       0
# 30                          True     31    38            30    969       0
# 31                         False     58    12            26    746       0
# 32                          True     12     1             1     14       0
#
# [33 rows x 25 columns]
